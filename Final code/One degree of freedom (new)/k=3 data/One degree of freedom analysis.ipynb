# %% [markdown]
# # Hyperbolic trajectory
# ----

# %% [markdown]
# Import modules and functions

# %%
import numpy as np
from numpy import cos, sin, cosh, sinh, tanh, array,pi, exp
from numpy.linalg import norm,solve
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import scipy.linalg
from System import MakeSystem, FindHyperbolicTrajectory, MakeLinearisedSolution
# %matplotlib qt

# %% [markdown]
# Set parameters of the system and find the hyperbolic trajectory, as well as the linearised hyperbolic trajectory

# %%
k = 3
ForcingParameters = array([.1,.7,-.15,2])
f,lminus,lplus,G,A = MakeSystem(k,ForcingParameters) 

XQ = MakeLinearisedSolution(ForcingParameters,lplus,lminus)
tmin,tmax = -10,10

N = 401
Xhyp,t,X0 = FindHyperbolicTrajectory(f,lminus,lplus,XQ,tmin,tmax,N,A)
# Out:
#  after 7 iterations an estimate with error of F =2.4505287786777723e-11 and delta = 5.391677075353767e-09was produced

# %% [markdown]
# Produce plots comparing the hyperbolic trajectory with the linearised system.

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')

ax.plot(Xhyp[:,0], Xhyp[:,1], t,linestyle='-',  linewidth=3, marker='o', label="Non-linear hyperbolic trajectory, quasi-periodic")
ax.plot( X0[:,0], X0[:,1],t,linestyle='--', linewidth=2, marker='x', label="Linearised hyperbolic trajectory, quasi-periodic")
plt.legend(fontsize=14)
ax.set_xlabel("$x$", fontsize=14)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
ax.set_ylabel("$y$", fontsize=14)
ax.set_zlabel("$t$", fontsize=14)
plt.show()

plt.plot(t, Xhyp[:,0], color='blue', linestyle='-',  linewidth=3, marker='o', label="Non-linear hyperbolic trajectory")
plt.plot(t, X0[:,0], color='red',  linestyle='--', linewidth=2, marker='x', label="Linearised hyperbolic trajectory")
plt.title("Hyperbolic trajectories $x$ component, quasi-periodic", fontsize=20)
plt.xlabel("$t$", fontsize=18)
plt.ylabel("$x$", fontsize=18)
plt.legend(fontsize=6)
plt.show()
plt.plot(t, Xhyp[:,1], color='blue', linestyle='-',  linewidth=3, marker='o', label="Non-linear hyperbolic trajectory")
plt.plot(t, X0[:,1], color='red',  linestyle='--', linewidth=2, marker='x', label="Linearised hyperbolic trajectory")
plt.title("Hyperbolic trajectories $y$ component, quasi-periodic", fontsize=20)
plt.xlabel("$t$", fontsize=18)
plt.ylabel("$y$", fontsize=18)
plt.legend(fontsize=6)
plt.show()

# %% [markdown]
# # Stable manifold data collection
# ---

# %% [markdown]
# Import functions to collect and process stable manifold data

# %%
from StableManifoldTrajectories import FindStableTrajectory,FindUnstableTrajectory
import scipy.io
import scipy.interpolate
from scipy.interpolate import RegularGridInterpolator
from scipy.interpolate import Rbf
from scipy.interpolate import LinearNDInterpolator
from scipy.interpolate import interp1d

# %% [markdown]
# ## ONLY RUN ONCE
# This code collects points on the stable manifold. This takes the longest to run, so only run if no available data for the model and forcing parameters.

# %%
stableCoord = np.linspace(-2,2,15)
unstableCoord =np.linspace(-2,2,15)
tindices = np.arange(int(N//5),int(4*N//5),25)
ySMvals = np.zeros((len(stableCoord),len(tindices)))
xSMvals = np.zeros((len(stableCoord),len(tindices)))
yUMvals = np.zeros((len(unstableCoord),len(tindices)))
xUMvals = np.zeros((len(unstableCoord),len(tindices)))


count =0
l=0
for J in tindices:
    for i in range(0,len(stableCoord)):
        p = stableCoord[i]
        X,tnew,X0,Jnew = FindStableTrajectory(f,lminus,lplus,tmin,tmax,N,p,J,Xhyp,A)
        ySMvals[i,l] = X[Jnew][1]   # output of function applied to (trange[J],P[i])
        xSMvals[i,l] = X[Jnew][0]   # output of function applied to (trange[J],P[i])
        count +=1 
        if int(100*count/(len(tindices)*len(stableCoord)))%5 ==0:
            print(str(int(100*count/(len(tindices)*len(stableCoord)))) + "% complete")
    l+=1
            
count =0
l=0
for J in tindices:
    for i in range(0,len(unstableCoord)):
        q = unstableCoord[i]
        X,tnew,X0,Jnew = FindUnstableTrajectory(f,lminus,lplus,tmin,tmax,N,q,J,Xhyp,A)
        yUMvals[i,l] = X[Jnew][1]   # output of function applied to (trange[J],P[i])
        xUMvals[i,l] = X[Jnew][0]   # output of function applied to (trange[J],P[i])
        count +=1 
        if int(100*count/(len(tindices)*len(unstableCoord)))%5 ==0:
            print(str(int(100*count/(len(tindices)*len(unstableCoord)))) + "% complete")
    l+=1
# Out:
# 0% complete
# 5% complete
# 10% complete
# 10% complete
# 15% complete
# 20% complete
# 20% complete
# 25% complete
# 30% complete
# 30% complete
# 35% complete
# 40% complete
# 40% complete
# 45% complete
# 50% complete
# 50% complete
# 55% complete
# 60% complete
# 60% complete
# 65% complete
# 70% complete
# 70% complete
# 75% complete
# 80% complete
# 80% complete
# 85% complete
# 90% complete
# 90% complete
# 95% complete
# 100% complete
# 0% complete
# 5% complete
# 10% complete
# 10% complete
# 15% complete
# 20% complete
# 20% complete
# 25% complete
# 30% complete
# 30% complete
# 35% complete
# 40% complete
# 40% complete
# 45% complete
# 50% complete
# 50% complete
# 55% complete
# 60% complete
# 60% complete
# 65% complete
# 70% complete
# 70% complete
# 75% complete
# 80% complete
# 80% complete
# 85% complete
# 90% complete
# 90% complete
# 95% complete
# 100% complete

# %% [markdown]
# xSM[i,j] stores the stable manifold x position corresponding to (stableCoord[i],t[tindices[l]])

# %%
np.save("tindices.npy",tindices)
np.save("t.npy",t)
np.save("Xhyp.npy",Xhyp)
np.save("k.npy", k)
np.save("ForcingParameters.npy",ForcingParameters)

np.save("stableCoord.npy",stableCoord)
np.save("ySMvals.npy",ySMvals)
np.save("xSMvals.npy",xSMvals)


np.save("unstableCoord.npy",unstableCoord)
np.save("yUMvals.npy",yUMvals)
np.save("xUMvals.npy",xUMvals)

# %% [markdown]
# ## Importing already computed data

# %%
tindices=np.load("tindices.npy")
t=np.load("t.npy")
Xhyp=np.load("Xhyp.npy")
k = np.load("k.npy")
ForcingParameters= np.load("ForcingParameters.npy")

stableCoord = np.load("stableCoord.npy")

ySMvals= np.load("ySMvals.npy")
xSMvals = np.load("xSMvals.npy")


unstableCoord = np.load("unstableCoord.npy")
yUMvals = np.load("yUMvals.npy")
xUMvals = np.load("xUMvals.npy")
f,lminus,lplus,G,A = MakeSystem(k,ForcingParameters) # system in stable/unstable coordinates

# %% [markdown]
# Here we create the parameterisations for the stable and unstable manifolds.

# %%
NewstableCoord,NewT = np.meshgrid(stableCoord,t[tindices], indexing='ij')

ySM = scipy.interpolate.LinearNDInterpolator(np.vstack((NewstableCoord.reshape(-1),NewT.reshape(-1))).transpose(),ySMvals.reshape(-1))
xSM = scipy.interpolate.LinearNDInterpolator(np.vstack((NewstableCoord.reshape(-1),NewT.reshape(-1))).transpose(),xSMvals.reshape(-1))

NewUnstableCoord,NewT = np.meshgrid(unstableCoord,t[tindices], indexing='ij')

yUM = scipy.interpolate.LinearNDInterpolator(np.vstack((NewUnstableCoord.reshape(-1),NewT.reshape(-1))).transpose(),yUMvals.reshape(-1))
xUM = scipy.interpolate.LinearNDInterpolator(np.vstack((NewUnstableCoord.reshape(-1),NewT.reshape(-1))).transpose(),xUMvals.reshape(-1))

# %% [markdown]
# ## Plots
# ----

# %% [markdown]
# This plot shows the hyperbolic trajectory alongside the stable and unstable manifolds and sample transition and non-transition trajectories.

# %%
fig = plt.figure(figsize=(7,9))
ax = fig.add_subplot(projection='3d')
ax.plot(Xhyp[:,0], Xhyp[:,1], t,linestyle='-',  linewidth=3, marker='x',color = 'green', label="Hyperbolic trajectory")
stableCoordinterp = np.linspace(stableCoord[0]+0.1,stableCoord[-1]-0.1,15)
unstableCoordinterp = np.linspace(unstableCoord[0]+0.1,unstableCoord[-1]-0.1,15)
tinterp = np.linspace(-6, 6, 10)
FontSize = 18
XS = 0*np.zeros((len(stableCoordinterp),len(tinterp)))
YS = 0*np.zeros((len(stableCoordinterp),len(tinterp)))
tS = 0*np.zeros((len(stableCoordinterp),len(tinterp)))
for i in range(0,len(stableCoordinterp)):
    for j in range(0,len(tinterp)):
        XS[i,j] = xSM(stableCoordinterp[i],tinterp[j])
        YS[i,j] = ySM(stableCoordinterp[i],tinterp[j])
        tS[i,j] = tinterp[j]
        
XU = 0*np.zeros((len(unstableCoordinterp),len(tinterp)))
YU = 0*np.zeros((len(unstableCoordinterp),len(tinterp)))
tU = 0*np.zeros((len(unstableCoordinterp),len(tinterp)))
for i in range(0,len(unstableCoordinterp)):
    for j in range(0,len(tinterp)):
        XU[i,j] = xUM(unstableCoordinterp[i],tinterp[j])
        YU[i,j] = yUM(unstableCoordinterp[i],tinterp[j])
        tU[i,j] = tinterp[j]
ax.plot_wireframe(XU, YU, tU, color = 'red',label = 'Unstable manifold',alpha = 0.5)
ax.plot_wireframe(XS, YS, tS, color = 'blue',label = 'Stable manifold',alpha = 0.5)
y0 = np.array([-2,3])
res = solve_ivp (f, [-3,3], y0 , method = "RK45" ,max_step =0.05 , rtol = 1e-8 )
y1 = res .y. transpose()
t1 = res .t  
ax.plot(y1[:,0],y1[:,1],t1, color = 'black', linewidth=3,label = 'Transition trajectory')

y0 = np.array([-2,1])
res = solve_ivp (f, [-3,3], y0 , method = "RK45" ,max_step =0.05 , rtol = 1e-8 )
y2 = res .y. transpose()
t2 = res .t  
ax.plot(y2[:,0],y2[:,1],t2, color = 'brown', linewidth=3,label = 'Non-transition trajectory')

ax.set_xlabel("$x$", fontsize=FontSize)
plt.legend(fontsize=FontSize,bbox_to_anchor=(-0, 1.2), loc='upper left')
ax.set_ylabel("$y$", fontsize=FontSize)
ax.set_zlabel("$t$", fontsize=FontSize)
ax.zaxis.set_tick_params(labelsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Time slice in original coordinates.

# %%
N = len(t)
fig = plt.figure(figsize=(15,15))
J =N//2
fig = plt.figure(figsize=(15,15))
FontSize = 20
plt.plot(Xhyp[J,0],Xhyp[J,0], linewidth=3, marker='o', label="Non-linear hyperbolic trajectory, quasi-periodic")
stableCoordinterp = np.linspace(stableCoord[0]+0.1,stableCoord[-1]-0.1,15)
unstableCoordinterp = np.linspace(unstableCoord[0]+0.1,unstableCoord[-1]-0.1,15)
YSvals =0*stableCoordinterp
XSvals =0*stableCoordinterp
for i in range(0,len(stableCoordinterp)):
    YSvals[i] = ySM(stableCoordinterp[i],t[J])
    XSvals[i] =xSM(stableCoordinterp[i],t[J])
plt.plot(XSvals,YSvals, color = 'blue', linewidth=3, marker='x',label = 'Stable manifold')
YUvals =0*unstableCoordinterp
XUvals =0*unstableCoordinterp
for i in range(0,len(unstableCoordinterp)):
    YUvals[i] = yUM(unstableCoordinterp[i],t[J])
    XUvals[i] =xUM(unstableCoordinterp[i],t[J])
plt.plot(XUvals,YUvals,color = 'red', linewidth=3, marker='x',label = 'Unstable manifold')
plt.legend(fontsize=FontSize)
plt.xlabel("$x$", fontsize=FontSize)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
plt.ylabel("$y$", fontsize=FontSize)
plt.show()

# %% [markdown]
# # Heat map
# ----

# %% [markdown]
# This is an interpolation of the hyperbolic trajectory.

# %%
xhyp = lambda s: np.interp(s,t,Xhyp[:,0])
yhyp = lambda s: np.interp(s,t,Xhyp[:,1])

# %% [markdown]
# Load saved data

# %%
x = np.load("initial conditions.npy")
z = np.load("Points moving over.npy")

# %% [markdown]
# Construct new data
# # Do not run if data already available!

# %%
def event(s,y):
    #return (Minv.dot(y) - np.array([xhyp(s),yhyp(s)]))[0]
    return y[0]- xhyp(s)
event.terminal = True
# functions to determine if it passes over
def passOver(y0):
    if event(0,y0) < 0:
        res = solve_ivp (f, [0,100], y0 , method = "RK45" , events=[event],max_step =0.05 , rtol = 1e-8 )
        y = res .y. transpose()
        t = res .t  
        s = t[-1]
        if s<100 and y[-1][1] > yhyp(s):  # the trajectories which move left to right
            return s
        elif y[-1][0]- xhyp(s) < 0: # trajectories which stay on left
            return -1
    else: 
        res = solve_ivp (f, [0,100], y0 , method = "RK45" , events=[event],max_step =0.05 , rtol = 1e-8 )
        y = res .y. transpose()
        t = res .t  
        s = t[-1]
        if s<100 and y[-1][1] < yhyp(s):  # the trajectories which move right to left 
            return -1
        elif y[-1][0]- xhyp(s) > 0: # trajectories which stay on right
            return 0



#creating and storing the data.

x = np.meshgrid(np.linspace(-3,xhyp(0)+.5,150) , np.linspace(yhyp(0)-0.5,3,150),indexing= 'ij')
z = np.zeros((np.shape(x)[1],np.shape(x)[2]))
count = 0
for i in range(0,np.shape(x)[1]):
    for j in range(0,np.shape(x)[2]):
        y0 = np.array([x[0][i,j],x[1][i,j]])
        z[i,j] = passOver(y0)
        count+=1
        if int(100000*count/(np.shape(x)[1]*np.shape(x)[2])) % 5 == 0:
            print(str(100*count/(np.shape(x)[1]*np.shape(x)[2])) + "% complete")
np.save("initial conditions.npy" , x)
np.save("Points moving over.npy", z)
# Out:
# 0.035555555555555556% complete
# 0.04% complete
# 0.07555555555555556% complete
# 0.08% complete
# 0.11555555555555555% complete
# 0.12% complete
# 0.15555555555555556% complete
# 0.16% complete
# 0.19555555555555557% complete
# 0.2% complete
# 0.23555555555555555% complete
# 0.24% complete
# 0.27555555555555555% complete
# 0.28% complete
# 0.31555555555555553% complete
# 0.32% complete
# 0.35555555555555557% complete
# 0.36% complete
# 0.39555555555555555% complete
# 0.4% complete
# 0.43555555555555553% complete
# 0.44% complete
# 0.47555555555555556% complete
# 0.48% complete
# 0.5155555555555555% complete
# 0.52% complete
# 0.5555555555555556% complete
# 0.56% complete
# 0.5955555555555555% complete
# 0.6% complete
# 0.6355555555555555% complete
# 0.64% complete
# 0.6755555555555556% complete
# 0.68% complete
# 0.7155555555555555% complete
# 0.72% complete
# 0.7555555555555555% complete
# 0.76% complete
# 0.7955555555555556% complete
# 0.8% complete
# 0.8355555555555556% complete
# 0.84% complete
# 0.8755555555555555% complete
# 0.88% complete
# 0.9155555555555556% complete
# 0.92% complete
# 0.9555555555555556% complete
# 0.96% complete
# 0.9955555555555555% complete
# 1.0% complete
# 1.0355555555555556% complete
# 1.04% complete
# 1.0755555555555556% complete
# 1.08% complete
# 1.1155555555555556% complete
# 1.12% complete
# 1.1555555555555554% complete
# 1.16% complete
# 1.1955555555555555% complete
# 1.2% complete
# 1.2355555555555555% complete
# 1.24% complete
# 1.2755555555555556% complete
# 1.28% complete
# 1.3155555555555556% complete
# 1.32% complete
# 1.3555555555555556% complete
# 1.36% complete
# 1.3955555555555557% complete
# 1.4% complete
# 1.4355555555555555% complete
# 1.44% complete
# 1.4755555555555555% complete
# 1.48% complete
# 1.5155555555555555% complete
# 1.52% complete
# 1.5555555555555556% complete
# 1.56% complete
# 1.5955555555555556% complete
# 1.6% complete
# 1.6355555555555557% complete
# 1.64% complete
# 1.6755555555555555% complete
# 1.68% complete
# 1.7155555555555555% complete
# 1.72% complete
# 1.7555555555555555% complete
# 1.76% complete
# 1.7955555555555556% complete
# 1.8% complete
# 1.8355555555555556% complete
# 1.84% complete
# 1.8755555555555556% complete
# 1.88% complete
# 1.9155555555555555% complete
# 1.92% complete
# 1.9555555555555555% complete
# 1.96% complete
# 1.9955555555555555% complete
# 2.0% complete
# 2.0355555555555553% complete
# 2.04% complete
# 2.0755555555555554% complete
# 2.08% complete
# 2.1155555555555554% complete
# 2.12% complete
# 2.1555555555555554% complete
# 2.16% complete
# 2.1955555555555555% complete
# 2.2% complete
# 2.2355555555555555% complete
# 2.24% complete
# 2.2755555555555556% complete
# 2.28% complete
# 2.3155555555555556% complete
# 2.32% complete
# 2.3555555555555556% complete
# 2.36% complete
# 2.3955555555555557% complete
# 2.4% complete
# 2.4355555555555557% complete
# 2.44% complete
# 2.4755555555555557% complete
# 2.48% complete
# 2.5155555555555558% complete
# 2.52% complete
# 2.5555555555555554% complete
# 2.56% complete
# 2.5955555555555554% complete
# 2.6% complete
# 2.6355555555555554% complete
# 2.64% complete
# 2.6755555555555555% complete
# 2.68% complete
# 2.7155555555555555% complete
# 2.72% complete
# 2.7555555555555555% complete
# 2.76% complete
# 2.7955555555555556% complete
# 2.8% complete
# 2.8355555555555556% complete
# 2.84% complete
# 2.8755555555555556% complete
# 2.88% complete
# 2.9155555555555557% complete
# 2.92% complete
# 2.9555555555555557% complete
# 2.96% complete
# 2.9955555555555557% complete
# 3.0% complete
# 3.0355555555555553% complete
# 3.04% complete
# 3.0755555555555554% complete
# 3.08% complete
# 3.1155555555555554% complete
# 3.12% complete
# 3.1555555555555554% complete
# 3.16% complete
# 3.1955555555555555% complete
# 3.2% complete
# 3.2355555555555555% complete
# 3.24% complete
# 3.2755555555555556% complete
# 3.28% complete
# 3.3155555555555556% complete
# 3.32% complete
# 3.3555555555555556% complete
# 3.36% complete
# 3.3955555555555557% complete
# 3.4% complete
# 3.4355555555555557% complete
# 3.44% complete
# 3.4755555555555557% complete
# 3.48% complete
# 3.5155555555555558% complete
# 3.52% complete
# 3.5555555555555554% complete
# 3.56% complete
# 3.5955555555555554% complete
# 3.6% complete
# 3.6355555555555554% complete
# 3.64% complete
# 3.6755555555555555% complete
# 3.68% complete
# 3.7155555555555555% complete
# 3.72% complete
# 3.7555555555555555% complete
# 3.76% complete
# 3.7955555555555556% complete
# 3.8% complete
# 3.8355555555555556% complete
# 3.84% complete
# 3.8755555555555556% complete
# 3.88% complete
# 3.9155555555555557% complete
# 3.92% complete
# 3.9555555555555557% complete
# 3.96% complete
# 3.9955555555555557% complete
# 4.0% complete
# 4.035555555555556% complete
# 4.04% complete
# 4.075555555555556% complete
# 4.08% complete
# 4.115555555555556% complete
# 4.12% complete
# 4.155555555555556% complete
# 4.16% complete
# 4.195555555555556% complete
# 4.2% complete
# 4.235555555555556% complete
# 4.24% complete
# 4.275555555555556% complete
# 4.28% complete
# 4.315555555555555% complete
# 4.32% complete
# 4.355555555555555% complete
# 4.36% complete
# 4.395555555555555% complete
# 4.4% complete
# 4.435555555555555% complete
# 4.44% complete
# 4.475555555555555% complete
# 4.48% complete
# 4.515555555555555% complete
# 4.52% complete
# 4.555555555555555% complete
# 4.56% complete
# 4.595555555555555% complete
# 4.6% complete
# 4.635555555555555% complete
# 4.64% complete
# 4.6755555555555555% complete
# 4.68% complete
# 4.7155555555555555% complete
# 4.72% complete
# 4.7555555555555555% complete
# 4.76% complete
# 4.795555555555556% complete
# 4.8% complete
# 4.835555555555556% complete
# 4.84% complete
# 4.875555555555556% complete
# 4.88% complete
# 4.915555555555556% complete
# 4.92% complete
# 4.955555555555556% complete
# 4.96% complete
# 4.995555555555556% complete
# 5.0% complete
# 5.035555555555556% complete
# 5.04% complete
# 5.075555555555556% complete
# 5.08% complete
# 5.115555555555556% complete
# 5.12% complete
# 5.155555555555556% complete
# 5.16% complete
# 5.195555555555556% complete
# 5.2% complete
# 5.235555555555556% complete
# 5.24% complete
# 5.275555555555556% complete
# 5.28% complete
# 5.315555555555555% complete
# 5.32% complete
# 5.355555555555555% complete
# 5.36% complete
# 5.395555555555555% complete
# 5.4% complete
# 5.435555555555555% complete
# 5.44% complete
# 5.475555555555555% complete
# 5.48% complete
# 5.515555555555555% complete
# 5.52% complete
# 5.555555555555555% complete
# 5.56% complete
# 5.595555555555555% complete
# 5.6% complete
# 5.635555555555555% complete
# 5.64% complete
# 5.6755555555555555% complete
# 5.68% complete
# 5.7155555555555555% complete
# 5.72% complete
# 5.7555555555555555% complete
# 5.76% complete
# 5.795555555555556% complete
# 5.8% complete
# 5.835555555555556% complete
# 5.84% complete
# 5.875555555555556% complete
# 5.88% complete
# 5.915555555555556% complete
# 5.92% complete
# 5.955555555555556% complete
# 5.96% complete
# 5.995555555555556% complete
# 6.0% complete
# 6.035555555555556% complete
# 6.04% complete
# 6.075555555555556% complete
# 6.08% complete
# 6.115555555555556% complete
# 6.12% complete
# 6.155555555555556% complete
# 6.16% complete
# 6.195555555555556% complete
# 6.2% complete
# 6.235555555555556% complete
# 6.24% complete
# 6.275555555555556% complete
# 6.28% complete
# 6.315555555555555% complete
# 6.32% complete
# 6.355555555555555% complete
# 6.36% complete
# 6.395555555555555% complete
# 6.4% complete
# 6.435555555555555% complete
# 6.44% complete
# 6.475555555555555% complete
# 6.48% complete
# 6.515555555555555% complete
# 6.52% complete
# 6.555555555555555% complete
# 6.56% complete
# 6.595555555555555% complete
# 6.6% complete
# 6.635555555555555% complete
# 6.64% complete
# 6.6755555555555555% complete
# 6.68% complete
# 6.7155555555555555% complete
# 6.72% complete
# 6.7555555555555555% complete
# 6.76% complete
# 6.795555555555556% complete
# 6.8% complete
# 6.835555555555556% complete
# 6.84% complete
# 6.875555555555556% complete
# 6.88% complete
# 6.915555555555556% complete
# 6.92% complete
# 6.955555555555556% complete
# 6.96% complete
# 6.995555555555556% complete
# 7.0% complete
# 7.035555555555556% complete
# 7.04% complete
# 7.075555555555556% complete
# 7.08% complete
# 7.115555555555556% complete
# 7.12% complete
# 7.155555555555556% complete
# 7.16% complete
# 7.195555555555556% complete
# 7.2% complete
# 7.235555555555556% complete
# 7.24% complete
# 7.275555555555556% complete
# 7.28% complete
# 7.315555555555555% complete
# 7.32% complete
# 7.355555555555555% complete
# 7.36% complete
# 7.395555555555555% complete
# 7.4% complete
# 7.435555555555555% complete
# 7.44% complete
# 7.475555555555555% complete
# 7.48% complete
# 7.515555555555555% complete
# 7.52% complete
# 7.555555555555555% complete
# 7.56% complete
# 7.595555555555555% complete
# 7.6% complete
# 7.635555555555555% complete
# 7.64% complete
# 7.6755555555555555% complete
# 7.68% complete
# 7.7155555555555555% complete
# 7.72% complete
# 7.7555555555555555% complete
# 7.76% complete
# 7.795555555555556% complete
# 7.8% complete
# 7.835555555555556% complete
# 7.84% complete
# 7.875555555555556% complete
# 7.88% complete
# 7.915555555555556% complete
# 7.92% complete
# 7.955555555555556% complete
# 7.96% complete
# 7.995555555555556% complete
# 8.0% complete
# 8.035555555555556% complete
# 8.04% complete
# 8.075555555555555% complete
# 8.08% complete
# 8.115555555555556% complete
# 8.12% complete
# 8.155555555555555% complete
# 8.16% complete
# 8.195555555555556% complete
# 8.2% complete
# 8.235555555555555% complete
# 8.24% complete
# 8.275555555555556% complete
# 8.28% complete
# 8.315555555555555% complete
# 8.32% complete
# 8.355555555555556% complete
# 8.36% complete
# 8.395555555555555% complete
# 8.4% complete
# 8.435555555555556% complete
# 8.44% complete
# 8.475555555555555% complete
# 8.48% complete
# 8.515555555555556% complete
# 8.52% complete
# 8.555555555555555% complete
# 8.56% complete
# 8.595555555555556% complete
# 8.6% complete
# 8.635555555555555% complete
# 8.64% complete
# 8.675555555555556% complete
# 8.68% complete
# 8.715555555555556% complete
# 8.72% complete
# 8.755555555555556% complete
# 8.76% complete
# 8.795555555555556% complete
# 8.8% complete
# 8.835555555555555% complete
# 8.84% complete
# 8.875555555555556% complete
# 8.88% complete
# 8.915555555555555% complete
# 8.92% complete
# 8.955555555555556% complete
# 8.96% complete
# 8.995555555555555% complete
# 9.0% complete
# 9.035555555555556% complete
# 9.04% complete
# 9.075555555555555% complete
# 9.08% complete
# 9.115555555555556% complete
# 9.12% complete
# 9.155555555555555% complete
# 9.16% complete
# 9.195555555555556% complete
# 9.2% complete
# 9.235555555555555% complete
# 9.24% complete
# 9.275555555555556% complete
# 9.28% complete
# 9.315555555555555% complete
# 9.32% complete
# 9.355555555555556% complete
# 9.36% complete
# 9.395555555555555% complete
# 9.4% complete
# 9.435555555555556% complete
# 9.44% complete
# 9.475555555555555% complete
# 9.48% complete
# 9.515555555555556% complete
# 9.52% complete
# 9.555555555555555% complete
# 9.56% complete
# 9.595555555555556% complete
# 9.6% complete
# 9.635555555555555% complete
# 9.64% complete
# 9.675555555555556% complete
# 9.68% complete
# 9.715555555555556% complete
# 9.72% complete
# 9.755555555555556% complete
# 9.76% complete
# 9.795555555555556% complete
# 9.8% complete
# 9.835555555555555% complete
# 9.84% complete
# 9.875555555555556% complete
# 9.88% complete
# 9.915555555555555% complete
# 9.92% complete
# 9.955555555555556% complete
# 9.96% complete
# 9.995555555555555% complete
# 10.0% complete
# 10.035555555555556% complete
# 10.04% complete
# 10.075555555555555% complete
# 10.08% complete
# 10.115555555555556% complete
# 10.12% complete
# 10.155555555555555% complete
# 10.16% complete
# 10.195555555555556% complete
# 10.2% complete
# 10.235555555555555% complete
# 10.24% complete
# 10.275555555555556% complete
# 10.28% complete
# 10.315555555555555% complete
# 10.32% complete
# 10.355555555555556% complete
# 10.36% complete
# 10.395555555555555% complete
# 10.4% complete
# 10.435555555555556% complete
# 10.44% complete
# 10.475555555555555% complete
# 10.48% complete
# 10.515555555555556% complete
# 10.52% complete
# 10.555555555555555% complete
# 10.56% complete
# 10.595555555555556% complete
# 10.6% complete
# 10.635555555555555% complete
# 10.64% complete
# 10.675555555555556% complete
# 10.68% complete
# 10.715555555555556% complete
# 10.72% complete
# 10.755555555555556% complete
# 10.76% complete
# 10.795555555555556% complete
# 10.8% complete
# 10.835555555555555% complete
# 10.84% complete
# 10.875555555555556% complete
# 10.88% complete
# 10.915555555555555% complete
# 10.92% complete
# 10.955555555555556% complete
# 10.96% complete
# 10.995555555555555% complete
# 11.0% complete
# 11.035555555555556% complete
# 11.04% complete
# 11.075555555555555% complete
# 11.08% complete
# 11.115555555555556% complete
# 11.12% complete
# 11.155555555555555% complete
# 11.16% complete
# 11.195555555555556% complete
# 11.2% complete
# 11.235555555555555% complete
# 11.24% complete
# 11.275555555555556% complete
# 11.28% complete
# 11.315555555555555% complete
# 11.32% complete
# 11.355555555555556% complete
# 11.36% complete
# 11.395555555555555% complete
# 11.4% complete
# 11.435555555555556% complete
# 11.44% complete
# 11.475555555555555% complete
# 11.48% complete
# 11.515555555555556% complete
# 11.52% complete
# 11.555555555555555% complete
# 11.56% complete
# 11.595555555555556% complete
# 11.6% complete
# 11.635555555555555% complete
# 11.64% complete
# 11.675555555555556% complete
# 11.68% complete
# 11.715555555555556% complete
# 11.72% complete
# 11.755555555555556% complete
# 11.76% complete
# 11.795555555555556% complete
# 11.8% complete
# 11.835555555555555% complete
# 11.84% complete
# 11.875555555555556% complete
# 11.88% complete
# 11.915555555555555% complete
# 11.92% complete
# 11.955555555555556% complete
# 11.96% complete
# 11.995555555555555% complete
# 12.0% complete
# 12.035555555555556% complete
# 12.04% complete
# 12.075555555555555% complete
# 12.08% complete
# 12.115555555555556% complete
# 12.12% complete
# 12.155555555555555% complete
# 12.16% complete
# 12.195555555555556% complete
# 12.2% complete
# 12.235555555555555% complete
# 12.24% complete
# 12.275555555555556% complete
# 12.28% complete
# 12.315555555555555% complete
# 12.32% complete
# 12.355555555555556% complete
# 12.36% complete
# 12.395555555555555% complete
# 12.4% complete
# 12.435555555555556% complete
# 12.44% complete
# 12.475555555555555% complete
# 12.48% complete
# 12.515555555555556% complete
# 12.52% complete
# 12.555555555555555% complete
# 12.56% complete
# 12.595555555555556% complete
# 12.6% complete
# 12.635555555555555% complete
# 12.64% complete
# 12.675555555555556% complete
# 12.68% complete
# 12.715555555555556% complete
# 12.72% complete
# 12.755555555555556% complete
# 12.76% complete
# 12.795555555555556% complete
# 12.8% complete
# 12.835555555555555% complete
# 12.84% complete
# 12.875555555555556% complete
# 12.88% complete
# 12.915555555555555% complete
# 12.92% complete
# 12.955555555555556% complete
# 12.96% complete
# 12.995555555555555% complete
# 13.0% complete
# 13.035555555555556% complete
# 13.04% complete
# 13.075555555555555% complete
# 13.08% complete
# 13.115555555555556% complete
# 13.12% complete
# 13.155555555555555% complete
# 13.16% complete
# 13.195555555555556% complete
# 13.2% complete
# 13.235555555555555% complete
# 13.24% complete
# 13.275555555555556% complete
# 13.28% complete
# 13.315555555555555% complete
# 13.32% complete
# 13.355555555555556% complete
# 13.36% complete
# 13.395555555555555% complete
# 13.4% complete
# 13.435555555555556% complete
# 13.44% complete
# 13.475555555555555% complete
# 13.48% complete
# 13.515555555555556% complete
# 13.52% complete
# 13.555555555555555% complete
# 13.56% complete
# 13.595555555555556% complete
# 13.6% complete
# 13.635555555555555% complete
# 13.64% complete
# 13.675555555555556% complete
# 13.68% complete
# 13.715555555555556% complete
# 13.72% complete
# 13.755555555555556% complete
# 13.76% complete
# 13.795555555555556% complete
# 13.8% complete
# 13.835555555555555% complete
# 13.84% complete
# 13.875555555555556% complete
# 13.88% complete
# 13.915555555555555% complete
# 13.92% complete
# 13.955555555555556% complete
# 13.96% complete
# 13.995555555555555% complete
# 14.0% complete
# 14.035555555555556% complete
# 14.04% complete
# 14.075555555555555% complete
# 14.08% complete
# 14.115555555555556% complete
# 14.12% complete
# 14.155555555555555% complete
# 14.16% complete
# 14.195555555555556% complete
# 14.2% complete
# 14.235555555555555% complete
# 14.24% complete
# 14.275555555555556% complete
# 14.28% complete
# 14.315555555555555% complete
# 14.32% complete
# 14.355555555555556% complete
# 14.36% complete
# 14.395555555555555% complete
# 14.4% complete
# 14.435555555555556% complete
# 14.44% complete
# 14.475555555555555% complete
# 14.48% complete
# 14.515555555555556% complete
# 14.52% complete
# 14.555555555555555% complete
# 14.56% complete
# 14.595555555555556% complete
# 14.6% complete
# 14.635555555555555% complete
# 14.64% complete
# 14.675555555555556% complete
# 14.68% complete
# 14.715555555555556% complete
# 14.72% complete
# 14.755555555555556% complete
# 14.76% complete
# 14.795555555555556% complete
# 14.8% complete
# 14.835555555555555% complete
# 14.84% complete
# 14.875555555555556% complete
# 14.88% complete
# 14.915555555555555% complete
# 14.92% complete
# 14.955555555555556% complete
# 14.96% complete
# 14.995555555555555% complete
# 15.0% complete
# 15.035555555555556% complete
# 15.04% complete
# 15.075555555555555% complete
# 15.08% complete
# 15.115555555555556% complete
# 15.12% complete
# 15.155555555555555% complete
# 15.16% complete
# 15.195555555555556% complete
# 15.2% complete
# 15.235555555555555% complete
# 15.24% complete
# 15.275555555555556% complete
# 15.28% complete
# 15.315555555555555% complete
# 15.32% complete
# 15.355555555555556% complete
# 15.36% complete
# 15.395555555555555% complete
# 15.4% complete
# 15.435555555555556% complete
# 15.44% complete
# 15.475555555555555% complete
# 15.48% complete
# 15.515555555555556% complete
# 15.52% complete
# 15.555555555555555% complete
# 15.56% complete
# 15.595555555555556% complete
# 15.6% complete
# 15.635555555555555% complete
# 15.64% complete
# 15.675555555555556% complete
# 15.68% complete
# 15.715555555555556% complete
# 15.72% complete
# 15.755555555555556% complete
# 15.76% complete
# 15.795555555555556% complete
# 15.8% complete
# 15.835555555555555% complete
# 15.84% complete
# 15.875555555555556% complete
# 15.88% complete
# 15.915555555555555% complete
# 15.92% complete
# 15.955555555555556% complete
# 15.96% complete
# 15.995555555555555% complete
# 16.0% complete
# 16.035555555555554% complete
# 16.04% complete
# 16.075555555555557% complete
# 16.08% complete
# 16.115555555555556% complete
# 16.12% complete
# 16.155555555555555% complete
# 16.16% complete
# 16.195555555555554% complete
# 16.2% complete
# 16.235555555555557% complete
# 16.24% complete
# 16.275555555555556% complete
# 16.28% complete
# 16.315555555555555% complete
# 16.32% complete
# 16.355555555555554% complete
# 16.36% complete
# 16.395555555555557% complete
# 16.4% complete
# 16.435555555555556% complete
# 16.44% complete
# 16.475555555555555% complete
# 16.48% complete
# 16.515555555555554% complete
# 16.52% complete
# 16.555555555555557% complete
# 16.56% complete
# 16.595555555555556% complete
# 16.6% complete
# 16.635555555555555% complete
# 16.64% complete
# 16.675555555555555% complete
# 16.68% complete
# 16.715555555555557% complete
# 16.72% complete
# 16.755555555555556% complete
# 16.76% complete
# 16.795555555555556% complete
# 16.8% complete
# 16.835555555555555% complete
# 16.84% complete
# 16.875555555555554% complete
# 16.88% complete
# 16.915555555555557% complete
# 16.92% complete
# 16.955555555555556% complete
# 16.96% complete
# 16.995555555555555% complete
# 17.0% complete
# 17.035555555555554% complete
# 17.04% complete
# 17.075555555555557% complete
# 17.08% complete
# 17.115555555555556% complete
# 17.12% complete
# 17.155555555555555% complete
# 17.16% complete
# 17.195555555555554% complete
# 17.2% complete
# 17.235555555555557% complete
# 17.24% complete
# 17.275555555555556% complete
# 17.28% complete
# 17.315555555555555% complete
# 17.32% complete
# 17.355555555555554% complete
# 17.36% complete
# 17.395555555555557% complete
# 17.4% complete
# 17.435555555555556% complete
# 17.44% complete
# 17.475555555555555% complete
# 17.48% complete
# 17.515555555555554% complete
# 17.52% complete
# 17.555555555555557% complete
# 17.56% complete
# 17.595555555555556% complete
# 17.6% complete
# 17.635555555555555% complete
# 17.64% complete
# 17.675555555555555% complete
# 17.68% complete
# 17.715555555555557% complete
# 17.72% complete
# 17.755555555555556% complete
# 17.76% complete
# 17.795555555555556% complete
# 17.8% complete
# 17.835555555555555% complete
# 17.84% complete
# 17.875555555555554% complete
# 17.88% complete
# 17.915555555555557% complete
# 17.92% complete
# 17.955555555555556% complete
# 17.96% complete
# 17.995555555555555% complete
# 18.0% complete
# 18.035555555555554% complete
# 18.04% complete
# 18.075555555555557% complete
# 18.08% complete
# 18.115555555555556% complete
# 18.12% complete
# 18.155555555555555% complete
# 18.16% complete
# 18.195555555555554% complete
# 18.2% complete
# 18.235555555555557% complete
# 18.24% complete
# 18.275555555555556% complete
# 18.28% complete
# 18.315555555555555% complete
# 18.32% complete
# 18.355555555555554% complete
# 18.36% complete
# 18.395555555555557% complete
# 18.4% complete
# 18.435555555555556% complete
# 18.44% complete
# 18.475555555555555% complete
# 18.48% complete
# 18.515555555555554% complete
# 18.52% complete
# 18.555555555555557% complete
# 18.56% complete
# 18.595555555555556% complete
# 18.6% complete
# 18.635555555555555% complete
# 18.64% complete
# 18.675555555555555% complete
# 18.68% complete
# 18.715555555555557% complete
# 18.72% complete
# 18.755555555555556% complete
# 18.76% complete
# 18.795555555555556% complete
# 18.8% complete
# 18.835555555555555% complete
# 18.84% complete
# 18.875555555555554% complete
# 18.88% complete
# 18.915555555555557% complete
# 18.92% complete
# 18.955555555555556% complete
# 18.96% complete
# 18.995555555555555% complete
# 19.0% complete
# 19.035555555555554% complete
# 19.04% complete
# 19.075555555555557% complete
# 19.08% complete
# 19.115555555555556% complete
# 19.12% complete
# 19.155555555555555% complete
# 19.16% complete
# 19.195555555555554% complete
# 19.2% complete
# 19.235555555555557% complete
# 19.24% complete
# 19.275555555555556% complete
# 19.28% complete
# 19.315555555555555% complete
# 19.32% complete
# 19.355555555555554% complete
# 19.36% complete
# 19.395555555555557% complete
# 19.4% complete
# 19.435555555555556% complete
# 19.44% complete
# 19.475555555555555% complete
# 19.48% complete
# 19.515555555555554% complete
# 19.52% complete
# 19.555555555555557% complete
# 19.56% complete
# 19.595555555555556% complete
# 19.6% complete
# 19.635555555555555% complete
# 19.64% complete
# 19.675555555555555% complete
# 19.68% complete
# 19.715555555555557% complete
# 19.72% complete
# 19.755555555555556% complete
# 19.76% complete
# 19.795555555555556% complete
# 19.8% complete
# 19.835555555555555% complete
# 19.84% complete
# 19.875555555555554% complete
# 19.88% complete
# 19.915555555555557% complete
# 19.92% complete
# 19.955555555555556% complete
# 19.96% complete
# 19.995555555555555% complete
# 20.0% complete
# 20.035555555555554% complete
# 20.04% complete
# 20.075555555555557% complete
# 20.08% complete
# 20.115555555555556% complete
# 20.12% complete
# 20.155555555555555% complete
# 20.16% complete
# 20.195555555555554% complete
# 20.2% complete
# 20.235555555555557% complete
# 20.24% complete
# 20.275555555555556% complete
# 20.28% complete
# 20.315555555555555% complete
# 20.32% complete
# 20.355555555555554% complete
# 20.36% complete
# 20.395555555555557% complete
# 20.4% complete
# 20.435555555555556% complete
# 20.44% complete
# 20.475555555555555% complete
# 20.48% complete
# 20.515555555555554% complete
# 20.52% complete
# 20.555555555555557% complete
# 20.56% complete
# 20.595555555555556% complete
# 20.6% complete
# 20.635555555555555% complete
# 20.64% complete
# 20.675555555555555% complete
# 20.68% complete
# 20.715555555555557% complete
# 20.72% complete
# 20.755555555555556% complete
# 20.76% complete
# 20.795555555555556% complete
# 20.8% complete
# 20.835555555555555% complete
# 20.84% complete
# 20.875555555555554% complete
# 20.88% complete
# 20.915555555555557% complete
# 20.92% complete
# 20.955555555555556% complete
# 20.96% complete
# 20.995555555555555% complete
# 21.0% complete
# 21.035555555555554% complete
# 21.04% complete
# 21.075555555555557% complete
# 21.08% complete
# 21.115555555555556% complete
# 21.12% complete
# 21.155555555555555% complete
# 21.16% complete
# 21.195555555555554% complete
# 21.2% complete
# 21.235555555555557% complete
# 21.24% complete
# 21.275555555555556% complete
# 21.28% complete
# 21.315555555555555% complete
# 21.32% complete
# 21.355555555555554% complete
# 21.36% complete
# 21.395555555555557% complete
# 21.4% complete
# 21.435555555555556% complete
# 21.44% complete
# 21.475555555555555% complete
# 21.48% complete
# 21.515555555555554% complete
# 21.52% complete
# 21.555555555555557% complete
# 21.56% complete
# 21.595555555555556% complete
# 21.6% complete
# 21.635555555555555% complete
# 21.64% complete
# 21.675555555555555% complete
# 21.68% complete
# 21.715555555555557% complete
# 21.72% complete
# 21.755555555555556% complete
# 21.76% complete
# 21.795555555555556% complete
# 21.8% complete
# 21.835555555555555% complete
# 21.84% complete
# 21.875555555555554% complete
# 21.88% complete
# 21.915555555555557% complete
# 21.92% complete
# 21.955555555555556% complete
# 21.96% complete
# 21.995555555555555% complete
# 22.0% complete
# 22.035555555555554% complete
# 22.04% complete
# 22.075555555555557% complete
# 22.08% complete
# 22.115555555555556% complete
# 22.12% complete
# 22.155555555555555% complete
# 22.16% complete
# 22.195555555555554% complete
# 22.2% complete
# 22.235555555555557% complete
# 22.24% complete
# 22.275555555555556% complete
# 22.28% complete
# 22.315555555555555% complete
# 22.32% complete
# 22.355555555555554% complete
# 22.36% complete
# 22.395555555555557% complete
# 22.4% complete
# 22.435555555555556% complete
# 22.44% complete
# 22.475555555555555% complete
# 22.48% complete
# 22.515555555555554% complete
# 22.52% complete
# 22.555555555555557% complete
# 22.56% complete
# 22.595555555555556% complete
# 22.6% complete
# 22.635555555555555% complete
# 22.64% complete
# 22.675555555555555% complete
# 22.68% complete
# 22.715555555555557% complete
# 22.72% complete
# 22.755555555555556% complete
# 22.76% complete
# 22.795555555555556% complete
# 22.8% complete
# 22.835555555555555% complete
# 22.84% complete
# 22.875555555555554% complete
# 22.88% complete
# 22.915555555555557% complete
# 22.92% complete
# 22.955555555555556% complete
# 22.96% complete
# 22.995555555555555% complete
# 23.0% complete
# 23.035555555555554% complete
# 23.04% complete
# 23.075555555555557% complete
# 23.08% complete
# 23.115555555555556% complete
# 23.12% complete
# 23.155555555555555% complete
# 23.16% complete
# 23.195555555555554% complete
# 23.2% complete
# 23.235555555555557% complete
# 23.24% complete
# 23.275555555555556% complete
# 23.28% complete
# 23.315555555555555% complete
# 23.32% complete
# 23.355555555555554% complete
# 23.36% complete
# 23.395555555555557% complete
# 23.4% complete
# 23.435555555555556% complete
# 23.44% complete
# 23.475555555555555% complete
# 23.48% complete
# 23.515555555555554% complete
# 23.52% complete
# 23.555555555555557% complete
# 23.56% complete
# 23.595555555555556% complete
# 23.6% complete
# 23.635555555555555% complete
# 23.64% complete
# 23.675555555555555% complete
# 23.68% complete
# 23.715555555555557% complete
# 23.72% complete
# 23.755555555555556% complete
# 23.76% complete
# 23.795555555555556% complete
# 23.8% complete
# 23.835555555555555% complete
# 23.84% complete
# 23.875555555555554% complete
# 23.88% complete
# 23.915555555555557% complete
# 23.92% complete
# 23.955555555555556% complete
# 23.96% complete
# 23.995555555555555% complete
# 24.0% complete
# 24.035555555555554% complete
# 24.04% complete
# 24.075555555555557% complete
# 24.08% complete
# 24.115555555555556% complete
# 24.12% complete
# 24.155555555555555% complete
# 24.16% complete
# 24.195555555555554% complete
# 24.2% complete
# 24.235555555555557% complete
# 24.24% complete
# 24.275555555555556% complete
# 24.28% complete
# 24.315555555555555% complete
# 24.32% complete
# 24.355555555555554% complete
# 24.36% complete
# 24.395555555555557% complete
# 24.4% complete
# 24.435555555555556% complete
# 24.44% complete
# 24.475555555555555% complete
# 24.48% complete
# 24.515555555555554% complete
# 24.52% complete
# 24.555555555555557% complete
# 24.56% complete
# 24.595555555555556% complete
# 24.6% complete
# 24.635555555555555% complete
# 24.64% complete
# 24.675555555555555% complete
# 24.68% complete
# 24.715555555555557% complete
# 24.72% complete
# 24.755555555555556% complete
# 24.76% complete
# 24.795555555555556% complete
# 24.8% complete
# 24.835555555555555% complete
# 24.84% complete
# 24.875555555555554% complete
# 24.88% complete
# 24.915555555555557% complete
# 24.92% complete
# 24.955555555555556% complete
# 24.96% complete
# 24.995555555555555% complete
# 25.0% complete
# 25.035555555555554% complete
# 25.04% complete
# 25.075555555555557% complete
# 25.08% complete
# 25.115555555555556% complete
# 25.12% complete
# 25.155555555555555% complete
# 25.16% complete
# 25.195555555555554% complete
# 25.2% complete
# 25.235555555555557% complete
# 25.24% complete
# 25.275555555555556% complete
# 25.28% complete
# 25.315555555555555% complete
# 25.32% complete
# 25.355555555555554% complete
# 25.36% complete
# 25.395555555555557% complete
# 25.4% complete
# 25.435555555555556% complete
# 25.44% complete
# 25.475555555555555% complete
# 25.48% complete
# 25.515555555555554% complete
# 25.52% complete
# 25.555555555555557% complete
# 25.56% complete
# 25.595555555555556% complete
# 25.6% complete
# 25.635555555555555% complete
# 25.64% complete
# 25.675555555555555% complete
# 25.68% complete
# 25.715555555555557% complete
# 25.72% complete
# 25.755555555555556% complete
# 25.76% complete
# 25.795555555555556% complete
# 25.8% complete
# 25.835555555555555% complete
# 25.84% complete
# 25.875555555555554% complete
# 25.88% complete
# 25.915555555555557% complete
# 25.92% complete
# 25.955555555555556% complete
# 25.96% complete
# 25.995555555555555% complete
# 26.0% complete
# 26.035555555555554% complete
# 26.04% complete
# 26.075555555555557% complete
# 26.08% complete
# 26.115555555555556% complete
# 26.12% complete
# 26.155555555555555% complete
# 26.16% complete
# 26.195555555555554% complete
# 26.2% complete
# 26.235555555555557% complete
# 26.24% complete
# 26.275555555555556% complete
# 26.28% complete
# 26.315555555555555% complete
# 26.32% complete
# 26.355555555555554% complete
# 26.36% complete
# 26.395555555555557% complete
# 26.4% complete
# 26.435555555555556% complete
# 26.44% complete
# 26.475555555555555% complete
# 26.48% complete
# 26.515555555555554% complete
# 26.52% complete
# 26.555555555555557% complete
# 26.56% complete
# 26.595555555555556% complete
# 26.6% complete
# 26.635555555555555% complete
# 26.64% complete
# 26.675555555555555% complete
# 26.68% complete
# 26.715555555555557% complete
# 26.72% complete
# 26.755555555555556% complete
# 26.76% complete
# 26.795555555555556% complete
# 26.8% complete
# 26.835555555555555% complete
# 26.84% complete
# 26.875555555555554% complete
# 26.88% complete
# 26.915555555555557% complete
# 26.92% complete
# 26.955555555555556% complete
# 26.96% complete
# 26.995555555555555% complete
# 27.0% complete
# 27.035555555555554% complete
# 27.04% complete
# 27.075555555555557% complete
# 27.08% complete
# 27.115555555555556% complete
# 27.12% complete
# 27.155555555555555% complete
# 27.16% complete
# 27.195555555555554% complete
# 27.2% complete
# 27.235555555555557% complete
# 27.24% complete
# 27.275555555555556% complete
# 27.28% complete
# 27.315555555555555% complete
# 27.32% complete
# 27.355555555555554% complete
# 27.36% complete
# 27.395555555555557% complete
# 27.4% complete
# 27.435555555555556% complete
# 27.44% complete
# 27.475555555555555% complete
# 27.48% complete
# 27.515555555555554% complete
# 27.52% complete
# 27.555555555555557% complete
# 27.56% complete
# 27.595555555555556% complete
# 27.6% complete
# 27.635555555555555% complete
# 27.64% complete
# 27.675555555555555% complete
# 27.68% complete
# 27.715555555555557% complete
# 27.72% complete
# 27.755555555555556% complete
# 27.76% complete
# 27.795555555555556% complete
# 27.8% complete
# 27.835555555555555% complete
# 27.84% complete
# 27.875555555555554% complete
# 27.88% complete
# 27.915555555555557% complete
# 27.92% complete
# 27.955555555555556% complete
# 27.96% complete
# 27.995555555555555% complete
# 28.0% complete
# 28.035555555555554% complete
# 28.04% complete
# 28.075555555555557% complete
# 28.08% complete
# 28.115555555555556% complete
# 28.12% complete
# 28.155555555555555% complete
# 28.16% complete
# 28.195555555555554% complete
# 28.2% complete
# 28.235555555555557% complete
# 28.24% complete
# 28.275555555555556% complete
# 28.28% complete
# 28.315555555555555% complete
# 28.32% complete
# 28.355555555555554% complete
# 28.36% complete
# 28.395555555555557% complete
# 28.4% complete
# 28.435555555555556% complete
# 28.44% complete
# 28.475555555555555% complete
# 28.48% complete
# 28.515555555555554% complete
# 28.52% complete
# 28.555555555555557% complete
# 28.56% complete
# 28.595555555555556% complete
# 28.6% complete
# 28.635555555555555% complete
# 28.64% complete
# 28.675555555555555% complete
# 28.68% complete
# 28.715555555555557% complete
# 28.72% complete
# 28.755555555555556% complete
# 28.76% complete
# 28.795555555555556% complete
# 28.8% complete
# 28.835555555555555% complete
# 28.84% complete
# 28.875555555555554% complete
# 28.88% complete
# 28.915555555555557% complete
# 28.92% complete
# 28.955555555555556% complete
# 28.96% complete
# 28.995555555555555% complete
# 29.0% complete
# 29.035555555555554% complete
# 29.04% complete
# 29.075555555555557% complete
# 29.08% complete
# 29.115555555555556% complete
# 29.12% complete
# 29.155555555555555% complete
# 29.16% complete
# 29.195555555555554% complete
# 29.2% complete
# 29.235555555555557% complete
# 29.24% complete
# 29.275555555555556% complete
# 29.28% complete
# 29.315555555555555% complete
# 29.32% complete
# 29.355555555555554% complete
# 29.36% complete
# 29.395555555555557% complete
# 29.4% complete
# 29.435555555555556% complete
# 29.44% complete
# 29.475555555555555% complete
# 29.48% complete
# 29.515555555555554% complete
# 29.52% complete
# 29.555555555555557% complete
# 29.56% complete
# 29.595555555555556% complete
# 29.6% complete
# 29.635555555555555% complete
# 29.64% complete
# 29.675555555555555% complete
# 29.68% complete
# 29.715555555555557% complete
# 29.72% complete
# 29.755555555555556% complete
# 29.76% complete
# 29.795555555555556% complete
# 29.8% complete
# 29.835555555555555% complete
# 29.84% complete
# 29.875555555555554% complete
# 29.88% complete
# 29.915555555555557% complete
# 29.92% complete
# 29.955555555555556% complete
# 29.96% complete
# 29.995555555555555% complete
# 30.0% complete
# 30.035555555555554% complete
# 30.04% complete
# 30.075555555555557% complete
# 30.08% complete
# 30.115555555555556% complete
# 30.12% complete
# 30.155555555555555% complete
# 30.16% complete
# 30.195555555555554% complete
# 30.2% complete
# 30.235555555555557% complete
# 30.24% complete
# 30.275555555555556% complete
# 30.28% complete
# 30.315555555555555% complete
# 30.32% complete
# 30.355555555555554% complete
# 30.36% complete
# 30.395555555555557% complete
# 30.4% complete
# 30.435555555555556% complete
# 30.44% complete
# 30.475555555555555% complete
# 30.48% complete
# 30.515555555555554% complete
# 30.52% complete
# 30.555555555555557% complete
# 30.56% complete
# 30.595555555555556% complete
# 30.6% complete
# 30.635555555555555% complete
# 30.64% complete
# 30.675555555555555% complete
# 30.68% complete
# 30.715555555555557% complete
# 30.72% complete
# 30.755555555555556% complete
# 30.76% complete
# 30.795555555555556% complete
# 30.8% complete
# 30.835555555555555% complete
# 30.84% complete
# 30.875555555555554% complete
# 30.88% complete
# 30.915555555555557% complete
# 30.92% complete
# 30.955555555555556% complete
# 30.96% complete
# 30.995555555555555% complete
# 31.0% complete
# 31.035555555555554% complete
# 31.04% complete
# 31.075555555555557% complete
# 31.08% complete
# 31.115555555555556% complete
# 31.12% complete
# 31.155555555555555% complete
# 31.16% complete
# 31.195555555555554% complete
# 31.2% complete
# 31.235555555555557% complete
# 31.24% complete
# 31.275555555555556% complete
# 31.28% complete
# 31.315555555555555% complete
# 31.32% complete
# 31.355555555555554% complete
# 31.36% complete
# 31.395555555555557% complete
# 31.4% complete
# 31.435555555555556% complete
# 31.44% complete
# 31.475555555555555% complete
# 31.48% complete
# 31.515555555555554% complete
# 31.52% complete
# 31.555555555555557% complete
# 31.56% complete
# 31.595555555555556% complete
# 31.6% complete
# 31.635555555555555% complete
# 31.64% complete
# 31.675555555555555% complete
# 31.68% complete
# 31.715555555555557% complete
# 31.72% complete
# 31.755555555555556% complete
# 31.76% complete
# 31.795555555555556% complete
# 31.8% complete
# 31.835555555555555% complete
# 31.84% complete
# 31.875555555555554% complete
# 31.88% complete
# 31.915555555555557% complete
# 31.92% complete
# 31.955555555555556% complete
# 31.96% complete
# 31.995555555555555% complete
# 32.0% complete
# 32.035555555555554% complete
# 32.04% complete
# 32.07555555555555% complete
# 32.08% complete
# 32.11555555555555% complete
# 32.12% complete
# 32.15555555555556% complete
# 32.16% complete
# 32.19555555555556% complete
# 32.2% complete
# 32.23555555555556% complete
# 32.24% complete
# 32.275555555555556% complete
# 32.28% complete
# 32.315555555555555% complete
# 32.32% complete
# 32.355555555555554% complete
# 32.36% complete
# 32.39555555555555% complete
# 32.4% complete
# 32.43555555555555% complete
# 32.44% complete
# 32.47555555555556% complete
# 32.48% complete
# 32.51555555555556% complete
# 32.52% complete
# 32.55555555555556% complete
# 32.56% complete
# 32.595555555555556% complete
# 32.6% complete
# 32.635555555555555% complete
# 32.64% complete
# 32.675555555555555% complete
# 32.68% complete
# 32.715555555555554% complete
# 32.72% complete
# 32.75555555555555% complete
# 32.76% complete
# 32.79555555555555% complete
# 32.8% complete
# 32.83555555555556% complete
# 32.84% complete
# 32.87555555555556% complete
# 32.88% complete
# 32.91555555555556% complete
# 32.92% complete
# 32.955555555555556% complete
# 32.96% complete
# 32.995555555555555% complete
# 33.0% complete
# 33.035555555555554% complete
# 33.04% complete
# 33.07555555555555% complete
# 33.08% complete
# 33.11555555555555% complete
# 33.12% complete
# 33.15555555555556% complete
# 33.16% complete
# 33.19555555555556% complete
# 33.2% complete
# 33.23555555555556% complete
# 33.24% complete
# 33.275555555555556% complete
# 33.28% complete
# 33.315555555555555% complete
# 33.32% complete
# 33.355555555555554% complete
# 33.36% complete
# 33.39555555555555% complete
# 33.4% complete
# 33.43555555555555% complete
# 33.44% complete
# 33.47555555555556% complete
# 33.48% complete
# 33.51555555555556% complete
# 33.52% complete
# 33.55555555555556% complete
# 33.56% complete
# 33.595555555555556% complete
# 33.6% complete
# 33.635555555555555% complete
# 33.64% complete
# 33.675555555555555% complete
# 33.68% complete
# 33.715555555555554% complete
# 33.72% complete
# 33.75555555555555% complete
# 33.76% complete
# 33.79555555555555% complete
# 33.8% complete
# 33.83555555555556% complete
# 33.84% complete
# 33.87555555555556% complete
# 33.88% complete
# 33.91555555555556% complete
# 33.92% complete
# 33.955555555555556% complete
# 33.96% complete
# 33.995555555555555% complete
# 34.0% complete
# 34.035555555555554% complete
# 34.04% complete
# 34.07555555555555% complete
# 34.08% complete
# 34.11555555555555% complete
# 34.12% complete
# 34.15555555555556% complete
# 34.16% complete
# 34.19555555555556% complete
# 34.2% complete
# 34.23555555555556% complete
# 34.24% complete
# 34.275555555555556% complete
# 34.28% complete
# 34.315555555555555% complete
# 34.32% complete
# 34.355555555555554% complete
# 34.36% complete
# 34.39555555555555% complete
# 34.4% complete
# 34.43555555555555% complete
# 34.44% complete
# 34.47555555555556% complete
# 34.48% complete
# 34.51555555555556% complete
# 34.52% complete
# 34.55555555555556% complete
# 34.56% complete
# 34.595555555555556% complete
# 34.6% complete
# 34.635555555555555% complete
# 34.64% complete
# 34.675555555555555% complete
# 34.68% complete
# 34.715555555555554% complete
# 34.72% complete
# 34.75555555555555% complete
# 34.76% complete
# 34.79555555555555% complete
# 34.8% complete
# 34.83555555555556% complete
# 34.84% complete
# 34.87555555555556% complete
# 34.88% complete
# 34.91555555555556% complete
# 34.92% complete
# 34.955555555555556% complete
# 34.96% complete
# 34.995555555555555% complete
# 35.0% complete
# 35.035555555555554% complete
# 35.04% complete
# 35.07555555555555% complete
# 35.08% complete
# 35.11555555555555% complete
# 35.12% complete
# 35.15555555555556% complete
# 35.16% complete
# 35.19555555555556% complete
# 35.2% complete
# 35.23555555555556% complete
# 35.24% complete
# 35.275555555555556% complete
# 35.28% complete
# 35.315555555555555% complete
# 35.32% complete
# 35.355555555555554% complete
# 35.36% complete
# 35.39555555555555% complete
# 35.4% complete
# 35.43555555555555% complete
# 35.44% complete
# 35.47555555555556% complete
# 35.48% complete
# 35.51555555555556% complete
# 35.52% complete
# 35.55555555555556% complete
# 35.56% complete
# 35.595555555555556% complete
# 35.6% complete
# 35.635555555555555% complete
# 35.64% complete
# 35.675555555555555% complete
# 35.68% complete
# 35.715555555555554% complete
# 35.72% complete
# 35.75555555555555% complete
# 35.76% complete
# 35.79555555555555% complete
# 35.8% complete
# 35.83555555555556% complete
# 35.84% complete
# 35.87555555555556% complete
# 35.88% complete
# 35.91555555555556% complete
# 35.92% complete
# 35.955555555555556% complete
# 35.96% complete
# 35.995555555555555% complete
# 36.0% complete
# 36.035555555555554% complete
# 36.04% complete
# 36.07555555555555% complete
# 36.08% complete
# 36.11555555555555% complete
# 36.12% complete
# 36.15555555555556% complete
# 36.16% complete
# 36.19555555555556% complete
# 36.2% complete
# 36.23555555555556% complete
# 36.24% complete
# 36.275555555555556% complete
# 36.28% complete
# 36.315555555555555% complete
# 36.32% complete
# 36.355555555555554% complete
# 36.36% complete
# 36.39555555555555% complete
# 36.4% complete
# 36.43555555555555% complete
# 36.44% complete
# 36.47555555555556% complete
# 36.48% complete
# 36.51555555555556% complete
# 36.52% complete
# 36.55555555555556% complete
# 36.56% complete
# 36.595555555555556% complete
# 36.6% complete
# 36.635555555555555% complete
# 36.64% complete
# 36.675555555555555% complete
# 36.68% complete
# 36.715555555555554% complete
# 36.72% complete
# 36.75555555555555% complete
# 36.76% complete
# 36.79555555555555% complete
# 36.8% complete
# 36.83555555555556% complete
# 36.84% complete
# 36.87555555555556% complete
# 36.88% complete
# 36.91555555555556% complete
# 36.92% complete
# 36.955555555555556% complete
# 36.96% complete
# 36.995555555555555% complete
# 37.0% complete
# 37.035555555555554% complete
# 37.04% complete
# 37.07555555555555% complete
# 37.08% complete
# 37.11555555555555% complete
# 37.12% complete
# 37.15555555555556% complete
# 37.16% complete
# 37.19555555555556% complete
# 37.2% complete
# 37.23555555555556% complete
# 37.24% complete
# 37.275555555555556% complete
# 37.28% complete
# 37.315555555555555% complete
# 37.32% complete
# 37.355555555555554% complete
# 37.36% complete
# 37.39555555555555% complete
# 37.4% complete
# 37.43555555555555% complete
# 37.44% complete
# 37.47555555555556% complete
# 37.48% complete
# 37.51555555555556% complete
# 37.52% complete
# 37.55555555555556% complete
# 37.56% complete
# 37.595555555555556% complete
# 37.6% complete
# 37.635555555555555% complete
# 37.64% complete
# 37.675555555555555% complete
# 37.68% complete
# 37.715555555555554% complete
# 37.72% complete
# 37.75555555555555% complete
# 37.76% complete
# 37.79555555555555% complete
# 37.8% complete
# 37.83555555555556% complete
# 37.84% complete
# 37.87555555555556% complete
# 37.88% complete
# 37.91555555555556% complete
# 37.92% complete
# 37.955555555555556% complete
# 37.96% complete
# 37.995555555555555% complete
# 38.0% complete
# 38.035555555555554% complete
# 38.04% complete
# 38.07555555555555% complete
# 38.08% complete
# 38.11555555555555% complete
# 38.12% complete
# 38.15555555555556% complete
# 38.16% complete
# 38.19555555555556% complete
# 38.2% complete
# 38.23555555555556% complete
# 38.24% complete
# 38.275555555555556% complete
# 38.28% complete
# 38.315555555555555% complete
# 38.32% complete
# 38.355555555555554% complete
# 38.36% complete
# 38.39555555555555% complete
# 38.4% complete
# 38.43555555555555% complete
# 38.44% complete
# 38.47555555555556% complete
# 38.48% complete
# 38.51555555555556% complete
# 38.52% complete
# 38.55555555555556% complete
# 38.56% complete
# 38.595555555555556% complete
# 38.6% complete
# 38.635555555555555% complete
# 38.64% complete
# 38.675555555555555% complete
# 38.68% complete
# 38.715555555555554% complete
# 38.72% complete
# 38.75555555555555% complete
# 38.76% complete
# 38.79555555555555% complete
# 38.8% complete
# 38.83555555555556% complete
# 38.84% complete
# 38.87555555555556% complete
# 38.88% complete
# 38.91555555555556% complete
# 38.92% complete
# 38.955555555555556% complete
# 38.96% complete
# 38.995555555555555% complete
# 39.0% complete
# 39.035555555555554% complete
# 39.04% complete
# 39.07555555555555% complete
# 39.08% complete
# 39.11555555555555% complete
# 39.12% complete
# 39.15555555555556% complete
# 39.16% complete
# 39.19555555555556% complete
# 39.2% complete
# 39.23555555555556% complete
# 39.24% complete
# 39.275555555555556% complete
# 39.28% complete
# 39.315555555555555% complete
# 39.32% complete
# 39.355555555555554% complete
# 39.36% complete
# 39.39555555555555% complete
# 39.4% complete
# 39.43555555555555% complete
# 39.44% complete
# 39.47555555555556% complete
# 39.48% complete
# 39.51555555555556% complete
# 39.52% complete
# 39.55555555555556% complete
# 39.56% complete
# 39.595555555555556% complete
# 39.6% complete
# 39.635555555555555% complete
# 39.64% complete
# 39.675555555555555% complete
# 39.68% complete
# 39.715555555555554% complete
# 39.72% complete
# 39.75555555555555% complete
# 39.76% complete
# 39.79555555555555% complete
# 39.8% complete
# 39.83555555555556% complete
# 39.84% complete
# 39.87555555555556% complete
# 39.88% complete
# 39.91555555555556% complete
# 39.92% complete
# 39.955555555555556% complete
# 39.96% complete
# 39.995555555555555% complete
# 40.0% complete
# 40.035555555555554% complete
# 40.04% complete
# 40.07555555555555% complete
# 40.08% complete
# 40.11555555555555% complete
# 40.12% complete
# 40.15555555555556% complete
# 40.16% complete
# 40.19555555555556% complete
# 40.2% complete
# 40.23555555555556% complete
# 40.24% complete
# 40.275555555555556% complete
# 40.28% complete
# 40.315555555555555% complete
# 40.32% complete
# 40.355555555555554% complete
# 40.36% complete
# 40.39555555555555% complete
# 40.4% complete
# 40.43555555555555% complete
# 40.44% complete
# 40.47555555555556% complete
# 40.48% complete
# 40.51555555555556% complete
# 40.52% complete
# 40.55555555555556% complete
# 40.56% complete
# 40.595555555555556% complete
# 40.6% complete
# 40.635555555555555% complete
# 40.64% complete
# 40.675555555555555% complete
# 40.68% complete
# 40.715555555555554% complete
# 40.72% complete
# 40.75555555555555% complete
# 40.76% complete
# 40.79555555555555% complete
# 40.8% complete
# 40.83555555555556% complete
# 40.84% complete
# 40.87555555555556% complete
# 40.88% complete
# 40.91555555555556% complete
# 40.92% complete
# 40.955555555555556% complete
# 40.96% complete
# 40.995555555555555% complete
# 41.0% complete
# 41.035555555555554% complete
# 41.04% complete
# 41.07555555555555% complete
# 41.08% complete
# 41.11555555555555% complete
# 41.12% complete
# 41.15555555555556% complete
# 41.16% complete
# 41.19555555555556% complete
# 41.2% complete
# 41.23555555555556% complete
# 41.24% complete
# 41.275555555555556% complete
# 41.28% complete
# 41.315555555555555% complete
# 41.32% complete
# 41.355555555555554% complete
# 41.36% complete
# 41.39555555555555% complete
# 41.4% complete
# 41.43555555555555% complete
# 41.44% complete
# 41.47555555555556% complete
# 41.48% complete
# 41.51555555555556% complete
# 41.52% complete
# 41.55555555555556% complete
# 41.56% complete
# 41.595555555555556% complete
# 41.6% complete
# 41.635555555555555% complete
# 41.64% complete
# 41.675555555555555% complete
# 41.68% complete
# 41.715555555555554% complete
# 41.72% complete
# 41.75555555555555% complete
# 41.76% complete
# 41.79555555555555% complete
# 41.8% complete
# 41.83555555555556% complete
# 41.84% complete
# 41.87555555555556% complete
# 41.88% complete
# 41.91555555555556% complete
# 41.92% complete
# 41.955555555555556% complete
# 41.96% complete
# 41.995555555555555% complete
# 42.0% complete
# 42.035555555555554% complete
# 42.04% complete
# 42.07555555555555% complete
# 42.08% complete
# 42.11555555555555% complete
# 42.12% complete
# 42.15555555555556% complete
# 42.16% complete
# 42.19555555555556% complete
# 42.2% complete
# 42.23555555555556% complete
# 42.24% complete
# 42.275555555555556% complete
# 42.28% complete
# 42.315555555555555% complete
# 42.32% complete
# 42.355555555555554% complete
# 42.36% complete
# 42.39555555555555% complete
# 42.4% complete
# 42.43555555555555% complete
# 42.44% complete
# 42.47555555555556% complete
# 42.48% complete
# 42.51555555555556% complete
# 42.52% complete
# 42.55555555555556% complete
# 42.56% complete
# 42.595555555555556% complete
# 42.6% complete
# 42.635555555555555% complete
# 42.64% complete
# 42.675555555555555% complete
# 42.68% complete
# 42.715555555555554% complete
# 42.72% complete
# 42.75555555555555% complete
# 42.76% complete
# 42.79555555555555% complete
# 42.8% complete
# 42.83555555555556% complete
# 42.84% complete
# 42.87555555555556% complete
# 42.88% complete
# 42.91555555555556% complete
# 42.92% complete
# 42.955555555555556% complete
# 42.96% complete
# 42.995555555555555% complete
# 43.0% complete
# 43.035555555555554% complete
# 43.04% complete
# 43.07555555555555% complete
# 43.08% complete
# 43.11555555555555% complete
# 43.12% complete
# 43.15555555555556% complete
# 43.16% complete
# 43.19555555555556% complete
# 43.2% complete
# 43.23555555555556% complete
# 43.24% complete
# 43.275555555555556% complete
# 43.28% complete
# 43.315555555555555% complete
# 43.32% complete
# ...
# 85.43555555555555% complete
# 85.44% complete
# 85.47555555555556% complete
# 85.48% complete
# 85.51555555555555% complete
# 85.52% complete
# 85.55555555555556% complete
# 85.56% complete
# 85.59555555555555% complete
# 85.6% complete
# 85.63555555555556% complete
# 85.64% complete
# 85.67555555555556% complete
# 85.68% complete
# 85.71555555555555% complete
# 85.72% complete
# 85.75555555555556% complete
# 85.76% complete
# 85.79555555555555% complete
# 85.8% complete
# 85.83555555555556% complete
# 85.84% complete
# 85.87555555555555% complete
# 85.88% complete
# 85.91555555555556% complete
# 85.92% complete
# 85.95555555555555% complete
# 85.96% complete
# 85.99555555555555% complete
# 86.0% complete
# 86.03555555555556% complete
# 86.04% complete
# 86.07555555555555% complete
# 86.08% complete
# 86.11555555555556% complete
# 86.12% complete
# 86.15555555555555% complete
# 86.16% complete
# 86.19555555555556% complete
# 86.2% complete
# 86.23555555555555% complete
# 86.24% complete
# 86.27555555555556% complete
# 86.28% complete
# 86.31555555555556% complete
# 86.32% complete
# 86.35555555555555% complete
# 86.36% complete
# 86.39555555555556% complete
# 86.4% complete
# 86.43555555555555% complete
# 86.44% complete
# 86.47555555555556% complete
# 86.48% complete
# 86.51555555555555% complete
# 86.52% complete
# 86.55555555555556% complete
# 86.56% complete
# 86.59555555555555% complete
# 86.6% complete
# 86.63555555555556% complete
# 86.64% complete
# 86.67555555555556% complete
# 86.68% complete
# 86.71555555555555% complete
# 86.72% complete
# 86.75555555555556% complete
# 86.76% complete
# 86.79555555555555% complete
# 86.8% complete
# 86.83555555555556% complete
# 86.84% complete
# 86.87555555555555% complete
# 86.88% complete
# 86.91555555555556% complete
# 86.92% complete
# 86.95555555555555% complete
# 86.96% complete
# 86.99555555555555% complete
# 87.0% complete
# 87.03555555555556% complete
# 87.04% complete
# 87.07555555555555% complete
# 87.08% complete
# 87.11555555555556% complete
# 87.12% complete
# 87.15555555555555% complete
# 87.16% complete
# 87.19555555555556% complete
# 87.2% complete
# 87.23555555555555% complete
# 87.24% complete
# 87.27555555555556% complete
# 87.28% complete
# 87.31555555555556% complete
# 87.32% complete
# 87.35555555555555% complete
# 87.36% complete
# 87.39555555555556% complete
# 87.4% complete
# 87.43555555555555% complete
# 87.44% complete
# 87.47555555555556% complete
# 87.48% complete
# 87.51555555555555% complete
# 87.52% complete
# 87.55555555555556% complete
# 87.56% complete
# 87.59555555555555% complete
# 87.6% complete
# 87.63555555555556% complete
# 87.64% complete
# 87.67555555555556% complete
# 87.68% complete
# 87.71555555555555% complete
# 87.72% complete
# 87.75555555555556% complete
# 87.76% complete
# 87.79555555555555% complete
# 87.8% complete
# 87.83555555555556% complete
# 87.84% complete
# 87.87555555555555% complete
# 87.88% complete
# 87.91555555555556% complete
# 87.92% complete
# 87.95555555555555% complete
# 87.96% complete
# 87.99555555555555% complete
# 88.0% complete
# 88.03555555555556% complete
# 88.04% complete
# 88.07555555555555% complete
# 88.08% complete
# 88.11555555555556% complete
# 88.12% complete
# 88.15555555555555% complete
# 88.16% complete
# 88.19555555555556% complete
# 88.2% complete
# 88.23555555555555% complete
# 88.24% complete
# 88.27555555555556% complete
# 88.28% complete
# 88.31555555555556% complete
# 88.32% complete
# 88.35555555555555% complete
# 88.36% complete
# 88.39555555555556% complete
# 88.4% complete
# 88.43555555555555% complete
# 88.44% complete
# 88.47555555555556% complete
# 88.48% complete
# 88.51555555555555% complete
# 88.52% complete
# 88.55555555555556% complete
# 88.56% complete
# 88.59555555555555% complete
# 88.6% complete
# 88.63555555555556% complete
# 88.64% complete
# 88.67555555555556% complete
# 88.68% complete
# 88.71555555555555% complete
# 88.72% complete
# 88.75555555555556% complete
# 88.76% complete
# 88.79555555555555% complete
# 88.8% complete
# 88.83555555555556% complete
# 88.84% complete
# 88.87555555555555% complete
# 88.88% complete
# 88.91555555555556% complete
# 88.92% complete
# 88.95555555555555% complete
# 88.96% complete
# 88.99555555555555% complete
# 89.0% complete
# 89.03555555555556% complete
# 89.04% complete
# 89.07555555555555% complete
# 89.08% complete
# 89.11555555555556% complete
# 89.12% complete
# 89.15555555555555% complete
# 89.16% complete
# 89.19555555555556% complete
# 89.2% complete
# 89.23555555555555% complete
# 89.24% complete
# 89.27555555555556% complete
# 89.28% complete
# 89.31555555555556% complete
# 89.32% complete
# 89.35555555555555% complete
# 89.36% complete
# 89.39555555555556% complete
# 89.4% complete
# 89.43555555555555% complete
# 89.44% complete
# 89.47555555555556% complete
# 89.48% complete
# 89.51555555555555% complete
# 89.52% complete
# 89.55555555555556% complete
# 89.56% complete
# 89.59555555555555% complete
# 89.6% complete
# 89.63555555555556% complete
# 89.64% complete
# 89.67555555555556% complete
# 89.68% complete
# 89.71555555555555% complete
# 89.72% complete
# 89.75555555555556% complete
# 89.76% complete
# 89.79555555555555% complete
# 89.8% complete
# 89.83555555555556% complete
# 89.84% complete
# 89.87555555555555% complete
# 89.88% complete
# 89.91555555555556% complete
# 89.92% complete
# 89.95555555555555% complete
# 89.96% complete
# 89.99555555555555% complete
# 90.0% complete
# 90.03555555555556% complete
# 90.04% complete
# 90.07555555555555% complete
# 90.08% complete
# 90.11555555555556% complete
# 90.12% complete
# 90.15555555555555% complete
# 90.16% complete
# 90.19555555555556% complete
# 90.2% complete
# 90.23555555555555% complete
# 90.24% complete
# 90.27555555555556% complete
# 90.28% complete
# 90.31555555555556% complete
# 90.32% complete
# 90.35555555555555% complete
# 90.36% complete
# 90.39555555555556% complete
# 90.4% complete
# 90.43555555555555% complete
# 90.44% complete
# 90.47555555555556% complete
# 90.48% complete
# 90.51555555555555% complete
# 90.52% complete
# 90.55555555555556% complete
# 90.56% complete
# 90.59555555555555% complete
# 90.6% complete
# 90.63555555555556% complete
# 90.64% complete
# 90.67555555555556% complete
# 90.68% complete
# 90.71555555555555% complete
# 90.72% complete
# 90.75555555555556% complete
# 90.76% complete
# 90.79555555555555% complete
# 90.8% complete
# 90.83555555555556% complete
# 90.84% complete
# 90.87555555555555% complete
# 90.88% complete
# 90.91555555555556% complete
# 90.92% complete
# 90.95555555555555% complete
# 90.96% complete
# 90.99555555555555% complete
# 91.0% complete
# 91.03555555555556% complete
# 91.04% complete
# 91.07555555555555% complete
# 91.08% complete
# 91.11555555555556% complete
# 91.12% complete
# 91.15555555555555% complete
# 91.16% complete
# 91.19555555555556% complete
# 91.2% complete
# 91.23555555555555% complete
# 91.24% complete
# 91.27555555555556% complete
# 91.28% complete
# 91.31555555555556% complete
# 91.32% complete
# 91.35555555555555% complete
# 91.36% complete
# 91.39555555555556% complete
# 91.4% complete
# 91.43555555555555% complete
# 91.44% complete
# 91.47555555555556% complete
# 91.48% complete
# 91.51555555555555% complete
# 91.52% complete
# 91.55555555555556% complete
# 91.56% complete
# 91.59555555555555% complete
# 91.6% complete
# 91.63555555555556% complete
# 91.64% complete
# 91.67555555555556% complete
# 91.68% complete
# 91.71555555555555% complete
# 91.72% complete
# 91.75555555555556% complete
# 91.76% complete
# 91.79555555555555% complete
# 91.8% complete
# 91.83555555555556% complete
# 91.84% complete
# 91.87555555555555% complete
# 91.88% complete
# 91.91555555555556% complete
# 91.92% complete
# 91.95555555555555% complete
# 91.96% complete
# 91.99555555555555% complete
# 92.0% complete
# 92.03555555555556% complete
# 92.04% complete
# 92.07555555555555% complete
# 92.08% complete
# 92.11555555555556% complete
# 92.12% complete
# 92.15555555555555% complete
# 92.16% complete
# 92.19555555555556% complete
# 92.2% complete
# 92.23555555555555% complete
# 92.24% complete
# 92.27555555555556% complete
# 92.28% complete
# 92.31555555555556% complete
# 92.32% complete
# 92.35555555555555% complete
# 92.36% complete
# 92.39555555555556% complete
# 92.4% complete
# 92.43555555555555% complete
# 92.44% complete
# 92.47555555555556% complete
# 92.48% complete
# 92.51555555555555% complete
# 92.52% complete
# 92.55555555555556% complete
# 92.56% complete
# 92.59555555555555% complete
# 92.6% complete
# 92.63555555555556% complete
# 92.64% complete
# 92.67555555555556% complete
# 92.68% complete
# 92.71555555555555% complete
# 92.72% complete
# 92.75555555555556% complete
# 92.76% complete
# 92.79555555555555% complete
# 92.8% complete
# 92.83555555555556% complete
# 92.84% complete
# 92.87555555555555% complete
# 92.88% complete
# 92.91555555555556% complete
# 92.92% complete
# 92.95555555555555% complete
# 92.96% complete
# 92.99555555555555% complete
# 93.0% complete
# 93.03555555555556% complete
# 93.04% complete
# 93.07555555555555% complete
# 93.08% complete
# 93.11555555555556% complete
# 93.12% complete
# 93.15555555555555% complete
# 93.16% complete
# 93.19555555555556% complete
# 93.2% complete
# 93.23555555555555% complete
# 93.24% complete
# 93.27555555555556% complete
# 93.28% complete
# 93.31555555555556% complete
# 93.32% complete
# 93.35555555555555% complete
# 93.36% complete
# 93.39555555555556% complete
# 93.4% complete
# 93.43555555555555% complete
# 93.44% complete
# 93.47555555555556% complete
# 93.48% complete
# 93.51555555555555% complete
# 93.52% complete
# 93.55555555555556% complete
# 93.56% complete
# 93.59555555555555% complete
# 93.6% complete
# 93.63555555555556% complete
# 93.64% complete
# 93.67555555555556% complete
# 93.68% complete
# 93.71555555555555% complete
# 93.72% complete
# 93.75555555555556% complete
# 93.76% complete
# 93.79555555555555% complete
# 93.8% complete
# 93.83555555555556% complete
# 93.84% complete
# 93.87555555555555% complete
# 93.88% complete
# 93.91555555555556% complete
# 93.92% complete
# 93.95555555555555% complete
# 93.96% complete
# 93.99555555555555% complete
# 94.0% complete
# 94.03555555555556% complete
# 94.04% complete
# 94.07555555555555% complete
# 94.08% complete
# 94.11555555555556% complete
# 94.12% complete
# 94.15555555555555% complete
# 94.16% complete
# 94.19555555555556% complete
# 94.2% complete
# 94.23555555555555% complete
# 94.24% complete
# 94.27555555555556% complete
# 94.28% complete
# 94.31555555555556% complete
# 94.32% complete
# 94.35555555555555% complete
# 94.36% complete
# 94.39555555555556% complete
# 94.4% complete
# 94.43555555555555% complete
# 94.44% complete
# 94.47555555555556% complete
# 94.48% complete
# 94.51555555555555% complete
# 94.52% complete
# 94.55555555555556% complete
# 94.56% complete
# 94.59555555555555% complete
# 94.6% complete
# 94.63555555555556% complete
# 94.64% complete
# 94.67555555555556% complete
# 94.68% complete
# 94.71555555555555% complete
# 94.72% complete
# 94.75555555555556% complete
# 94.76% complete
# 94.79555555555555% complete
# 94.8% complete
# 94.83555555555556% complete
# 94.84% complete
# 94.87555555555555% complete
# 94.88% complete
# 94.91555555555556% complete
# 94.92% complete
# 94.95555555555555% complete
# 94.96% complete
# 94.99555555555555% complete
# 95.0% complete
# 95.03555555555556% complete
# 95.04% complete
# 95.07555555555555% complete
# 95.08% complete
# 95.11555555555556% complete
# 95.12% complete
# 95.15555555555555% complete
# 95.16% complete
# 95.19555555555556% complete
# 95.2% complete
# 95.23555555555555% complete
# 95.24% complete
# 95.27555555555556% complete
# 95.28% complete
# 95.31555555555556% complete
# 95.32% complete
# 95.35555555555555% complete
# 95.36% complete
# 95.39555555555556% complete
# 95.4% complete
# 95.43555555555555% complete
# 95.44% complete
# 95.47555555555556% complete
# 95.48% complete
# 95.51555555555555% complete
# 95.52% complete
# 95.55555555555556% complete
# 95.56% complete
# 95.59555555555555% complete
# 95.6% complete
# 95.63555555555556% complete
# 95.64% complete
# 95.67555555555556% complete
# 95.68% complete
# 95.71555555555555% complete
# 95.72% complete
# 95.75555555555556% complete
# 95.76% complete
# 95.79555555555555% complete
# 95.8% complete
# 95.83555555555556% complete
# 95.84% complete
# 95.87555555555555% complete
# 95.88% complete
# 95.91555555555556% complete
# 95.92% complete
# 95.95555555555555% complete
# 95.96% complete
# 95.99555555555555% complete
# 96.0% complete
# 96.03555555555556% complete
# 96.04% complete
# 96.07555555555555% complete
# 96.08% complete
# 96.11555555555556% complete
# 96.12% complete
# 96.15555555555555% complete
# 96.16% complete
# 96.19555555555556% complete
# 96.2% complete
# 96.23555555555555% complete
# 96.24% complete
# 96.27555555555556% complete
# 96.28% complete
# 96.31555555555556% complete
# 96.32% complete
# 96.35555555555555% complete
# 96.36% complete
# 96.39555555555556% complete
# 96.4% complete
# 96.43555555555555% complete
# 96.44% complete
# 96.47555555555556% complete
# 96.48% complete
# 96.51555555555555% complete
# 96.52% complete
# 96.55555555555556% complete
# 96.56% complete
# 96.59555555555555% complete
# 96.6% complete
# 96.63555555555556% complete
# 96.64% complete
# 96.67555555555556% complete
# 96.68% complete
# 96.71555555555555% complete
# 96.72% complete
# 96.75555555555556% complete
# 96.76% complete
# 96.79555555555555% complete
# 96.8% complete
# 96.83555555555556% complete
# 96.84% complete
# 96.87555555555555% complete
# 96.88% complete
# 96.91555555555556% complete
# 96.92% complete
# 96.95555555555555% complete
# 96.96% complete
# 96.99555555555555% complete
# 97.0% complete
# 97.03555555555556% complete
# 97.04% complete
# 97.07555555555555% complete
# 97.08% complete
# 97.11555555555556% complete
# 97.12% complete
# 97.15555555555555% complete
# 97.16% complete
# 97.19555555555556% complete
# 97.2% complete
# 97.23555555555555% complete
# 97.24% complete
# 97.27555555555556% complete
# 97.28% complete
# 97.31555555555556% complete
# 97.32% complete
# 97.35555555555555% complete
# 97.36% complete
# 97.39555555555556% complete
# 97.4% complete
# 97.43555555555555% complete
# 97.44% complete
# 97.47555555555556% complete
# 97.48% complete
# 97.51555555555555% complete
# 97.52% complete
# 97.55555555555556% complete
# 97.56% complete
# 97.59555555555555% complete
# 97.6% complete
# 97.63555555555556% complete
# 97.64% complete
# 97.67555555555556% complete
# 97.68% complete
# 97.71555555555555% complete
# 97.72% complete
# 97.75555555555556% complete
# 97.76% complete
# 97.79555555555555% complete
# 97.8% complete
# 97.83555555555556% complete
# 97.84% complete
# 97.87555555555555% complete
# 97.88% complete
# 97.91555555555556% complete
# 97.92% complete
# 97.95555555555555% complete
# 97.96% complete
# 97.99555555555555% complete
# 98.0% complete
# 98.03555555555556% complete
# 98.04% complete
# 98.07555555555555% complete
# 98.08% complete
# 98.11555555555556% complete
# 98.12% complete
# 98.15555555555555% complete
# 98.16% complete
# 98.19555555555556% complete
# 98.2% complete
# 98.23555555555555% complete
# 98.24% complete
# 98.27555555555556% complete
# 98.28% complete
# 98.31555555555556% complete
# 98.32% complete
# 98.35555555555555% complete
# 98.36% complete
# 98.39555555555556% complete
# 98.4% complete
# 98.43555555555555% complete
# 98.44% complete
# 98.47555555555556% complete
# 98.48% complete
# 98.51555555555555% complete
# 98.52% complete
# 98.55555555555556% complete
# 98.56% complete
# 98.59555555555555% complete
# 98.6% complete
# 98.63555555555556% complete
# 98.64% complete
# 98.67555555555556% complete
# 98.68% complete
# 98.71555555555555% complete
# 98.72% complete
# 98.75555555555556% complete
# 98.76% complete
# 98.79555555555555% complete
# 98.8% complete
# 98.83555555555556% complete
# 98.84% complete
# 98.87555555555555% complete
# 98.88% complete
# 98.91555555555556% complete
# 98.92% complete
# 98.95555555555555% complete
# 98.96% complete
# 98.99555555555555% complete
# 99.0% complete
# 99.03555555555556% complete
# 99.04% complete
# 99.07555555555555% complete
# 99.08% complete
# 99.11555555555556% complete
# 99.12% complete
# 99.15555555555555% complete
# 99.16% complete
# 99.19555555555556% complete
# 99.2% complete
# 99.23555555555555% complete
# 99.24% complete
# 99.27555555555556% complete
# 99.28% complete
# 99.31555555555556% complete
# 99.32% complete
# 99.35555555555555% complete
# 99.36% complete
# 99.39555555555556% complete
# 99.4% complete
# 99.43555555555555% complete
# 99.44% complete
# 99.47555555555556% complete
# 99.48% complete
# 99.51555555555555% complete
# 99.52% complete
# 99.55555555555556% complete
# 99.56% complete
# 99.59555555555555% complete
# 99.6% complete
# 99.63555555555556% complete
# 99.64% complete
# 99.67555555555556% complete
# 99.68% complete
# 99.71555555555555% complete
# 99.72% complete
# 99.75555555555556% complete
# 99.76% complete
# 99.79555555555555% complete
# 99.8% complete
# 99.83555555555556% complete
# 99.84% complete
# 99.87555555555555% complete
# 99.88% complete
# 99.91555555555556% complete
# 99.92% complete
# 99.95555555555555% complete
# 99.96% complete
# 99.99555555555555% complete
# 100.0% complete

# %% [markdown]
# Produce plots, heat map of which points transition and time to transition.

# %%
X,Y = x
YSvals =0*stableCoordinterp
XSvals =0*stableCoordinterp
for i in range(0,len(stableCoordinterp)):
    YSvals[i] = ySM(stableCoordinterp[i],0)
    XSvals[i] =xSM(stableCoordinterp[i],0)
YUvals =0*unstableCoordinterp
XUvals =0*unstableCoordinterp
for i in range(0,len(unstableCoordinterp)):
    YUvals[i] = yUM(unstableCoordinterp[i],0)
    XUvals[i] =xUM(unstableCoordinterp[i],0)

fig = plt.figure(figsize=(8,8))
plt.xlabel("$x$", fontsize=18)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
plt.ylabel("$y$", fontsize=18)
import matplotlib.colors
custom_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["red","orange","yellow","green"])
plt.imshow(z.transpose(), vmin = -1,vmax = 3, cmap = custom_cmap, origin = 'lower',alpha = .8,extent = [np.amin(X),np.amax(X),np.amin(Y),np.amax(Y)])

plt.plot(XSvals[0:XSvals.shape[0]//2+1],YSvals[0:XSvals.shape[0]//2+1], color = 'blue', linewidth=3, marker='x',label = 'Stable manifold')
plt.plot(xhyp(0),yhyp(0), linewidth=3, marker='o', color = 'black', label="Hyperbolic trajectory")
plt.legend(fontsize=18)
plt.colorbar()
plt.ylim(np.amin(Y),np.amax(Y))
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')
X,Y = x
ax.plot_surface(X,Y,z)
plt.show()
