# %% [markdown]
# # Hyperbolic trajectory
# ----

# %%
import numpy as np
from numpy import cos, sin, cosh, sinh, tanh, array,pi, exp
from numpy.linalg import norm,solve
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import scipy.linalg
from System import MakeSystem, FindHyperbolicTrajectory, MakeLinearisedSolution
# %matplotlib qt

# %%
k = 1
ForcingParameters = array([.1,.7,-.15,2])
f,lminus,lplus,G = MakeSystem(k,ForcingParameters) # system in stable/unstable coordinates

XQ = MakeLinearisedSolution(ForcingParameters,lplus,lminus)
tmin,tmax = -2,10

N = 201
Xhyp,t,X0 = FindHyperbolicTrajectory(f,lminus,lplus,XQ,tmin,tmax,N)
# Out:
#  after 6 iterations an estimate with error of F =5.924255865251801e-12 and delta = 1.0727648856633993e-09was produced

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')

ax.plot(Xhyp[:,0], Xhyp[:,1], t,linestyle='-',  linewidth=3, marker='o', label="Non-linear hyperbolic trajectory, quasi-periodic")
ax.plot( X0[:,0], X0[:,1],t,linestyle='--', linewidth=2, marker='x', label="Linearised hyperbolic trajectory, quasi-periodic")
plt.legend(fontsize=14)
ax.set_xlabel("$x$", fontsize=14)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
ax.set_ylabel("$y$", fontsize=14)
ax.set_zlabel("$t$", fontsize=14)
plt.show()

plt.plot(t, Xhyp[:,0], color='blue', linestyle='-',  linewidth=3, marker='o', label="Non-linear hyperbolic trajectory")
plt.plot(t, X0[:,0], color='red',  linestyle='--', linewidth=2, marker='x', label="Linearised hyperbolic trajectory")
plt.title("Hyperbolic trajectories $x$ component, quasi-periodic", fontsize=20)
plt.xlabel("$t$", fontsize=18)
plt.ylabel("$x$", fontsize=18)
plt.legend(fontsize=6)
plt.show()
plt.plot(t, Xhyp[:,1], color='blue', linestyle='-',  linewidth=3, marker='o', label="Non-linear hyperbolic trajectory")
plt.plot(t, X0[:,1], color='red',  linestyle='--', linewidth=2, marker='x', label="Linearised hyperbolic trajectory")
plt.title("Hyperbolic trajectories $y$ component, quasi-periodic", fontsize=20)
plt.xlabel("$t$", fontsize=18)
plt.ylabel("$y$", fontsize=18)
plt.legend(fontsize=6)
plt.show()

# %% [markdown]
# # Stable manifold data collection
# ---

# %%
from StableManifoldTrajectories import FindStableTrajectory,FindUnstableTrajectory
import scipy.io
import scipy.interpolate
from scipy.interpolate import RegularGridInterpolator
from scipy.interpolate import Rbf
from scipy.interpolate import LinearNDInterpolator
from scipy.interpolate import interp1d

# %%
from numpy import nan
def ySM(p,s):
    for l in range(0,len(tindices)):
        if t[tindices[l]] == s:
            return  interpyS[t[tindices[l]]](array([p]))
        elif t[l] < s and t[l+1]> s:
            t0 = t[tindices[l]] 
            t1 = t[tindices[l+1]]
            break
    if l< len(tindices) - 2:
        SM1 = interpyS[t0](array([p]))
        SM2 = interpyS[t1](array([p]))
        return SM1 + ((s - t0)/(t1-t0))*(SM2-SM1)
    else: 
        return nan
def xUM(q,s):
    for l in range(0,len(tindices)):
        if t[tindices[l]] == s:
            return  interpxU[t[tindices[l]]](array([q]))
        elif t[l] < s and t[l+1]> s:
            t0 = t[tindices[l]] 
            t1 = t[tindices[l+1]]
            break
    if l< len(tindices) - 2:
        UM1 = interpxU[t0](array([q]))
        UM2 = interpxU[t1](array([q]))
        return UM1 + ((s - t0)/(t1-t0))*(UM2-UM1)
    else: 
        return nan

# %%
def makeinterpyS(P,yvals,tindices):
    interpyS = {  t[tindices[0]]: interp1d(P,yvals[:len(P)] )}
    for l in range(1,len(tindices)):
        interpyS[t[tindices[l]]] = interp1d(P,yvals[l*len(P):(l+1)*len(P)],kind = 'linear')
    return interpyS

def makeinterpxU(Q,xvals,tindices):
    interpxU = {  t[tindices[0]]: interp1d(Q,xvals[:len(Q)] )}
    for l in range(1,len(tindices)):
        interpxU[t[tindices[l]]] = interp1d(Q,xvals[l*len(Q):(l+1)*len(Q)],kind = 'linear')
    return interpxU

# %% [markdown]
# Data collection code

# %%
P = np.linspace(-2,2,10)
Q =np.linspace(-2,2,10)
tmin,tmax = -3,3
t = np.linspace(tmin,tmax,N)
N = 201
trangestart = N//5
trangeend = 4*trangestart
tindices = np.arange(int(N//5),int(4*N//5),10)
#tindices = np.array([3*N//4])
trange = t[tindices]
yvals = np.zeros(len(P)*len(tindices))
xvals = np.zeros(len(Q)*len(tindices))

l=0
# %matplotlib qt
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
ax.plot(Xhyp[:,0], Xhyp[:,1], t,linestyle='--', color = 'red', linewidth=3, marker='o', label="Non-linear hyperbolic trajectory")
for J in tindices:
    for i in range(0,len(P)):
        p = P[i]
        X,tnew,X0,Jnew = FindStableTrajectory(f,lminus,lplus,tmin,tmax,N,p,J,Xhyp)
       # if l==0:
        #    ax.plot(X[Jnew:,0], X[Jnew:,1], tnew[Jnew:],linestyle='-', color = 'blue', linewidth=1, marker='o', label="Non-linear Stable manifold trajectory")
        #else:
        #    ax.plot(X[Jnew:,0], X[Jnew:,1], tnew[Jnew:],linestyle='-', color = 'blue', linewidth=1, marker='o')
        yvals[l] = X[Jnew][1]   # output of function applied to (trange[J],P[i])
        q = Q[i]
        X,tnew,X0,Jnew = FindUnstableTrajectory(f,lminus,lplus,tmin,tmax,N,q,J,Xhyp)
     #   if l==0:
    #        ax.plot(X[Jnew:,0], X[Jnew:,1], tnew[Jnew:],linestyle='-', color = 'blue', linewidth=1, marker='o', label="Non-linear Stable manifold trajectory")
     #   else:
     #       ax.plot(X[Jnew:,0], X[Jnew:,1], tnew[Jnew:],linestyle='-', color = 'blue', linewidth=1, marker='o')
        xvals[l] = X[Jnew][0]   # output of function applied to (trange[J],P[i])
        l+=1
        if int(100*l/(len(tindices)*len(P)))%5 ==0:
            print(str(int(100*l/(len(tindices)*len(P)))) + "% complete")
np.save("P.npy",P)
np.save("yvals.npy",yvals)
np.save("tindices.npy",tindices)
np.save("t.npy",t)
np.save("Xhyp.npy",Xhyp)
np.save("Q.npy",Q)
np.save("xvals.npy",xvals)
np.save("ForcingParameters.npy",ForcingParameters)
Q =np.linspace(-2,2,10)
N = 200

trangestart = N//5
trangeend = 4*trangestart
# Out:
#  after 24 iterations an estimate with error of F =2.647003862815804e-09 and delta = 7.439556712298887e-08was produced
#  after 28 iterations an estimate with error of F =4.941010816894762e-09 and delta = 9.081669007182962e-08was produced
# 0% complete
#  after 21 iterations an estimate with error of F =2.820043066907825e-09 and delta = 8.174885845527707e-08was produced
#  after 31 iterations an estimate with error of F =5.3317604587292965e-09 and delta = 8.995999096947681e-08was produced
#  after 17 iterations an estimate with error of F =2.1952371766128482e-09 and delta = 6.587987319300114e-08was produced
#  after 38 iterations an estimate with error of F =6.114757324283562e-09 and delta = 9.149127776956434e-08was produced
#  after 12 iterations an estimate with error of F =7.577784839702273e-10 and delta = 2.240299328475067e-08was produced
#  after 22 iterations an estimate with error of F =3.8151763310705066e-09 and delta = 8.352369412178062e-08was produced
#  after 7 iterations an estimate with error of F =1.0713936996273451e-10 and delta = 9.691502455840674e-09was produced
#  after 10 iterations an estimate with error of F =3.987768946665542e-10 and delta = 3.680918338282518e-08was produced
#  after 7 iterations an estimate with error of F =3.5421498580957036e-12 and delta = 1.1324879083278962e-09was produced
#  after 9 iterations an estimate with error of F =4.514672497691818e-10 and delta = 4.858154776111443e-08was produced
# 5% complete
#  after 7 iterations an estimate with error of F =8.3124738817742e-10 and delta = 5.875106391407525e-08was produced
#  after 11 iterations an estimate with error of F =3.8706241019615367e-10 and delta = 2.1073521174744456e-08was produced
# 5% complete
#  after 12 iterations an estimate with error of F =1.7809571179949134e-09 and delta = 5.281374896550948e-08was produced
#  after 24 iterations an estimate with error of F =4.816216673989581e-09 and delta = 9.686866845586882e-08was produced
#  after 16 iterations an estimate with error of F =2.2163207117697444e-09 and delta = 6.755152911482232e-08was produced
#  after 37 iterations an estimate with error of F =4.349913089329903e-09 and delta = 6.611089759258907e-08was produced
#  after 19 iterations an estimate with error of F =2.527840413522915e-09 and delta = 7.579125993253042e-08was produced
#  after 31 iterations an estimate with error of F =3.369304955973276e-09 and delta = 5.724666965855963e-08was produced
#  after 23 iterations an estimate with error of F =3.0076735163008357e-09 and delta = 8.560512846105592e-08was produced
#  after 28 iterations an estimate with error of F =3.866348545738351e-09 and delta = 7.220728507244855e-08was produced
#  after 21 iterations an estimate with error of F =1.6194245911029589e-09 and delta = 4.739663248184377e-08was produced
#  after 30 iterations an estimate with error of F =4.664784969441376e-09 and delta = 8.149206861038652e-08was produced
# 10% complete
#  after 17 iterations an estimate with error of F =1.5390722704193774e-09 and delta = 4.6301753951014325e-08was produced
#  after 36 iterations an estimate with error of F =6.29868837019754e-09 and delta = 9.676751568595425e-08was produced
# 10% complete
#  after 12 iterations an estimate with error of F =7.492762383509537e-10 and delta = 2.2090294422390872e-08was produced
#  after 29 iterations an estimate with error of F =5.161791994159716e-09 and delta = 9.235921688542363e-08was produced
#  after 7 iterations an estimate with error of F =1.911652113503079e-10 and delta = 2.081912591529757e-08was produced
#  after 11 iterations an estimate with error of F =9.927434919782877e-10 and delta = 4.8141020633557815e-08was produced
#  after 7 iterations an estimate with error of F =3.2459789763406547e-12 and delta = 2.2272132681233118e-10was produced
#  after 9 iterations an estimate with error of F =6.97561175678429e-11 and delta = 9.97752516170077e-09was produced
#  after 7 iterations an estimate with error of F =1.806075184843047e-10 and delta = 3.4511628847354355e-08was produced
#  after 11 iterations an estimate with error of F =2.33880012874646e-10 and delta = 2.3603348331692545e-08was produced
#  after 12 iterations an estimate with error of F =1.7534478074349937e-09 and delta = 5.199988996639003e-08was produced
#  after 17 iterations an estimate with error of F =2.4463567725710086e-09 and delta = 5.8540677793616714e-08was produced
# 15% complete
#  after 16 iterations an estimate with error of F =2.8562576824177755e-09 and delta = 8.688965490363781e-08was produced
#  after 36 iterations an estimate with error of F =6.264891375130903e-09 and delta = 9.677299543786567e-08was produced
# 15% complete
#  after 20 iterations an estimate with error of F =1.5706231820362877e-09 and delta = 4.6778341783530454e-08was produced
#  after 32 iterations an estimate with error of F =4.2320505990391005e-09 and delta = 6.921474098249834e-08was produced
#  after 23 iterations an estimate with error of F =2.6573008109606834e-09 and delta = 7.60682099042272e-08was produced
#  after 28 iterations an estimate with error of F =4.424860201651556e-09 and delta = 8.17179444381528e-08was produced
#  after 21 iterations an estimate with error of F =1.4703022064924743e-09 and delta = 4.326700051531097e-08was produced
#  after 31 iterations an estimate with error of F =4.1650017996521384e-09 and delta = 7.098934647775243e-08was produced
#  after 17 iterations an estimate with error of F =1.725881089519952e-09 and delta = 5.204887281905064e-08was produced
#  after 38 iterations an estimate with error of F =5.274482896912928e-09 and delta = 7.918166211883563e-08was produced
#  after 12 iterations an estimate with error of F =1.552220672067932e-09 and delta = 4.576571933459203e-08was produced
#  after 23 iterations an estimate with error of F =3.829692300306285e-09 and delta = 8.009089485752786e-08was produced
# 20% complete
#  after 7 iterations an estimate with error of F =8.334663965721797e-10 and delta = 6.429143936824926e-08was produced
#  after 10 iterations an estimate with error of F =2.4387682001868264e-10 and delta = 2.4061223184884328e-08was produced
# 20% complete
#  after 6 iterations an estimate with error of F =1.108044293927857e-10 and delta = 8.796679685314216e-08was produced
#  after 10 iterations an estimate with error of F =7.193691810299591e-11 and delta = 8.170599823675372e-09was produced
#  after 8 iterations an estimate with error of F =1.0175424474691923e-09 and delta = 5.844234572397529e-08was produced
#  after 11 iterations an estimate with error of F =2.2679635895657535e-10 and delta = 2.2361269258780795e-08was produced
#  after 12 iterations an estimate with error of F =1.3211729965479299e-09 and delta = 3.917856135003707e-08was produced
#  after 24 iterations an estimate with error of F =2.8125749713281224e-09 and delta = 5.8819738786699494e-08was produced
#  after 16 iterations an estimate with error of F =1.3202216738943403e-09 and delta = 4.007095093120054e-08was produced
#  after 37 iterations an estimate with error of F =4.989842008460091e-09 and delta = 7.571869474734297e-08was produced
#  after 19 iterations an estimate with error of F =3.246336189183257e-09 and delta = 9.621961011309594e-08was produced
#  after 31 iterations an estimate with error of F =4.324601296217205e-09 and delta = 7.272454767362527e-08was produced
# 25% complete
#  after 23 iterations an estimate with error of F =2.4209123694183862e-09 and delta = 6.950796037985173e-08was produced
#  after 29 iterations an estimate with error of F =3.805779413499353e-09 and delta = 6.8247932721744e-08was produced
# 25% complete
#  after 20 iterations an estimate with error of F =2.5611518736644964e-09 and delta = 7.58322699198161e-08was produced
#  after 33 iterations an estimate with error of F =5.727997333994918e-09 and delta = 9.19999293505439e-08was produced
#  after 16 iterations an estimate with error of F =2.7132648793495846e-09 and delta = 8.200778397280913e-08was produced
#  after 36 iterations an estimate with error of F =5.24967611022182e-09 and delta = 8.188198749450126e-08was produced
#  after 11 iterations an estimate with error of F =2.718704664474174e-09 and delta = 8.103504203151557e-08was produced
#  after 13 iterations an estimate with error of F =1.2076960654537874e-09 and delta = 3.8840493465887785e-08was produced
#  after 7 iterations an estimate with error of F =9.736627058973661e-10 and delta = 9.90938454573153e-08was produced
#  after 8 iterations an estimate with error of F =2.9096750472092063e-11 and delta = 5.865998490953365e-09was produced
#  after 7 iterations an estimate with error of F =4.3674733474164056e-10 and delta = 6.74610459748245e-08was produced
#  after 11 iterations an estimate with error of F =3.419172168629861e-11 and delta = 3.5270662612376986e-09was produced
# 30% complete
#  after 9 iterations an estimate with error of F =1.3016109582534716e-09 and delta = 5.770029075817811e-08was produced
#  after 15 iterations an estimate with error of F =2.5317509941211012e-09 and delta = 7.524091683788279e-08was produced
# 30% complete
#  after 13 iterations an estimate with error of F =2.454107941530904e-09 and delta = 7.322276799813254e-08was produced
#  after 34 iterations an estimate with error of F =4.3426435403496255e-09 and delta = 7.229605627283026e-08was produced
#  after 13 iterations an estimate with error of F =3.067546924521069e-09 and delta = 9.274209502467894e-08was produced
#  after 34 iterations an estimate with error of F =5.686251742913283e-09 and delta = 8.944796534028675e-08was produced
#  after 20 iterations an estimate with error of F =1.4500065028935336e-09 and delta = 4.273214283140729e-08was produced
#  after 30 iterations an estimate with error of F =3.048227124203186e-09 and delta = 5.3740125208424004e-08was produced
#  after 23 iterations an estimate with error of F =1.7622826777842391e-09 and delta = 5.0778466029697064e-08was produced
#  after 30 iterations an estimate with error of F =3.0828632874262555e-09 and delta = 5.439929588620006e-08was produced
#  after 19 iterations an estimate with error of F =2.9874083458761548e-09 and delta = 8.914783149579079e-08was produced
#  after 35 iterations an estimate with error of F =5.510557910511562e-09 and delta = 8.588809542927689e-08was produced
# 35% complete
#  after 15 iterations an estimate with error of F =1.946566426546264e-09 and delta = 5.869416544350447e-08was produced
#  after 31 iterations an estimate with error of F =4.2386464519102385e-09 and delta = 7.20642952900143e-08was produced
# 35% complete
#  after 10 iterations an estimate with error of F =1.3874620411652275e-09 and delta = 4.588169443321372e-08was produced
#  after 11 iterations an estimate with error of F =9.92901218627495e-10 and delta = 4.764733017137015e-08was produced
#  after 8 iterations an estimate with error of F =4.3534486997899695e-10 and delta = 4.8506227683807125e-08was produced
#  after 6 iterations an estimate with error of F =1.4151234954321737e-12 and delta = 6.264774660638164e-10was produced
#  after 8 iterations an estimate with error of F =4.2714062017785676e-10 and delta = 4.6206541584542235e-08was produced
#  after 11 iterations an estimate with error of F =1.6757365729522025e-10 and delta = 1.6592174830509634e-08was produced
#  after 10 iterations an estimate with error of F =1.9322280219082353e-09 and delta = 6.256004135094441e-08was produced
#  after 19 iterations an estimate with error of F =2.004971294159627e-09 and delta = 5.0172770306329454e-08was produced
#  after 13 iterations an estimate with error of F =2.996838349999784e-09 and delta = 9.02777264713062e-08was produced
#  after 36 iterations an estimate with error of F =6.1065107796456346e-09 and delta = 9.596918291327181e-08was produced
# 40% complete
#  after 17 iterations an estimate with error of F =2.6870312186407334e-09 and delta = 8.076801756126679e-08was produced
#  after 33 iterations an estimate with error of F =4.18434168268202e-09 and delta = 6.755614283158424e-08was produced
# 40% complete
#  after 20 iterations an estimate with error of F =3.3853529569639846e-09 and delta = 9.923983525835546e-08was produced
#  after 29 iterations an estimate with error of F =3.960648059121752e-09 and delta = 7.091019134315149e-08was produced
#  after 22 iterations an estimate with error of F =3.321256737879017e-09 and delta = 9.559647618143968e-08was produced
#  after 29 iterations an estimate with error of F =5.085628324992232e-09 and delta = 9.080937756616717e-08was produced
#  after 19 iterations an estimate with error of F =1.7924111018250474e-09 and delta = 5.361384308635992e-08was produced
#  after 35 iterations an estimate with error of F =3.812069813315475e-09 and delta = 6.052493323545364e-08was produced
#  after 14 iterations an estimate with error of F =2.062256052459326e-09 and delta = 6.20080948690795e-08was produced
#  after 35 iterations an estimate with error of F =3.979112629760994e-09 and delta = 6.376613786131744e-08was produced
#  after 9 iterations an estimate with error of F =1.0232785987096826e-09 and delta = 3.9234405838440644e-08was produced
#  after 13 iterations an estimate with error of F =1.0847307268892045e-09 and delta = 3.979596493133371e-08was produced
# 45% complete
#  after 7 iterations an estimate with error of F =2.4293487504656582e-11 and delta = 3.976208269310406e-09was produced
#  after 9 iterations an estimate with error of F =1.1502571381277612e-11 and delta = 1.9506327668822835e-09was produced
# 45% complete
#  after 7 iterations an estimate with error of F =9.843695703217069e-11 and delta = 2.443879509835383e-08was produced
#  after 11 iterations an estimate with error of F =5.669635635985925e-11 and delta = 5.803374766748496e-09was produced
#  after 9 iterations an estimate with error of F =1.2836627978951072e-09 and delta = 3.9021493927221455e-08was produced
#  after 16 iterations an estimate with error of F =2.716999986914536e-09 and delta = 7.305703405252907e-08was produced
#  after 15 iterations an estimate with error of F =1.0506146787509224e-09 and delta = 3.1741250499874826e-08was produced
#  after 35 iterations an estimate with error of F =4.132482228597773e-09 and delta = 6.724327669669166e-08was produced
#  after 18 iterations an estimate with error of F =2.7670409173189095e-09 and delta = 8.305559902488161e-08was produced
#  after 33 iterations an estimate with error of F =5.45350714725232e-09 and delta = 8.671229577519622e-08was produced
#  after 21 iterations an estimate with error of F =2.133058415261743e-09 and delta = 6.256707160738874e-08was produced
#  after 29 iterations an estimate with error of F =4.344460090598647e-09 and delta = 7.6900893028197e-08was produced
# 50% complete
#  after 24 iterations an estimate with error of F =1.7846145034518161e-09 and delta = 5.056133660899544e-08was produced
#  after 29 iterations an estimate with error of F =4.539597304821302e-09 and delta = 8.150914004993363e-08was produced
# 50% complete
#  after 20 iterations an estimate with error of F =2.0453853678185977e-09 and delta = 6.045148251258326e-08was produced
#  after 34 iterations an estimate with error of F =4.167699542639877e-09 and delta = 6.701381445843342e-08was produced
#  after 15 iterations an estimate with error of F =2.0171423686121265e-09 and delta = 6.098542986093978e-08was produced
#  after 37 iterations an estimate with error of F =4.5573466822552135e-09 and delta = 7.096965259003018e-08was produced
#  after 10 iterations an estimate with error of F =5.718475587689015e-10 and delta = 1.872435299396621e-08was produced
#  after 15 iterations an estimate with error of F =1.5800485055535886e-09 and delta = 4.937528688881449e-08was produced
#  after 7 iterations an estimate with error of F =2.850989865519486e-12 and delta = 1.088652184924817e-09was produced
#  after 9 iterations an estimate with error of F =3.822649140268357e-10 and delta = 3.300638498229393e-08was produced
#  after 7 iterations an estimate with error of F =3.233720032399263e-11 and delta = 8.638488385099322e-09was produced
#  after 10 iterations an estimate with error of F =5.924737117046157e-11 and delta = 5.442355055058677e-09was produced
# 55% complete
#  after 9 iterations an estimate with error of F =1.0076889186888203e-09 and delta = 3.265753781461186e-08was produced
#  after 13 iterations an estimate with error of F =2.3421206025681013e-09 and delta = 7.158221604491269e-08was produced
# 55% complete
#  after 14 iterations an estimate with error of F =1.5107141150734237e-09 and delta = 4.544746119517951e-08was produced
#  after 33 iterations an estimate with error of F =5.206094391404826e-09 and delta = 8.665429476641195e-08was produced
#  after 18 iterations an estimate with error of F =1.309578387710532e-09 and delta = 3.9569131607416585e-08was produced
#  after 34 iterations an estimate with error of F =4.4617280706235845e-09 and delta = 7.021252868855088e-08was produced
#  after 20 iterations an estimate with error of F =2.587678026617991e-09 and delta = 7.662073639424974e-08was produced
#  after 29 iterations an estimate with error of F =4.71158858972983e-09 and delta = 8.296063741998308e-08was produced
#  after 25 iterations an estimate with error of F =3.3436268832905697e-09 and delta = 9.270192455086202e-08was produced
#  after 30 iterations an estimate with error of F =3.3807263420582127e-09 and delta = 5.931649587621233e-08was produced
#  after 22 iterations an estimate with error of F =2.320945139840645e-09 and delta = 6.703750236876473e-08was produced
#  after 35 iterations an estimate with error of F =4.66942310212231e-09 and delta = 7.280194551368729e-08was produced
# 60% complete
#  after 17 iterations an estimate with error of F =2.8577989136505744e-09 and delta = 8.616351767853055e-08was produced
#  after 32 iterations an estimate with error of F =5.107134866490555e-09 and delta = 8.709335482179885e-08was produced
# 60% complete
#  after 12 iterations an estimate with error of F =9.144878969981205e-10 and delta = 2.735586641784107e-08was produced
#  after 13 iterations an estimate with error of F =1.3196506202005751e-09 and delta = 4.530828646648676e-08was produced
#  after 7 iterations an estimate with error of F =2.4995602851745973e-10 and delta = 2.0123564568287277e-08was produced
#  after 8 iterations an estimate with error of F =8.215889346045416e-10 and delta = 9.549561074888311e-08was produced
#  after 7 iterations an estimate with error of F =1.6673904652917036e-11 and delta = 1.8260036030378738e-09was produced
#  after 9 iterations an estimate with error of F =6.750473676095803e-10 and delta = 7.877033266330201e-08was produced
#  after 9 iterations an estimate with error of F =5.710972323031301e-10 and delta = 2.5142110191540874e-08was produced
#  after 16 iterations an estimate with error of F =2.1067507154501008e-09 and delta = 5.9147865991773535e-08was produced
#  after 12 iterations an estimate with error of F =1.668037176232716e-09 and delta = 4.956427518828433e-08was produced
#  after 37 iterations an estimate with error of F =5.5791451439375675e-09 and delta = 8.595367480273684e-08was produced
# 65% complete
#  after 15 iterations an estimate with error of F =3.2059539793836694e-09 and delta = 9.750002691784078e-08was produced
#  after 33 iterations an estimate with error of F =4.264034108766113e-09 and delta = 6.915877904654484e-08was produced
# 65% complete
#  after 19 iterations an estimate with error of F =1.495463281934522e-09 and delta = 4.4817078749649624e-08was produced
#  after 29 iterations an estimate with error of F =3.5017461751440885e-09 and delta = 6.30689223693691e-08was produced
#  after 26 iterations an estimate with error of F =2.436800118817449e-09 and delta = 6.718371129647126e-08was produced
#  after 31 iterations an estimate with error of F =3.39710991853251e-09 and delta = 5.749984618107877e-08was produced
#  after 23 iterations an estimate with error of F =2.081437694294823e-09 and delta = 5.952045490203079e-08was produced
#  after 36 iterations an estimate with error of F =5.933894331500749e-09 and delta = 9.040049333508057e-08was produced
#  after 18 iterations an estimate with error of F =3.0966733839001e-09 and delta = 9.271507583116228e-08was produced
#  after 25 iterations an estimate with error of F =4.180165572097765e-09 and delta = 8.299182610815164e-08was produced
#  after 13 iterations an estimate with error of F =1.0283608872827553e-09 and delta = 3.064796536206044e-08was produced
#  after 11 iterations an estimate with error of F =6.366509956493325e-10 and delta = 3.323822338087219e-08was produced
# 70% complete
#  after 8 iterations an estimate with error of F =9.715160372902987e-11 and delta = 6.681605179991367e-09was produced
#  after 7 iterations an estimate with error of F =4.2656590989390505e-12 and delta = 2.5434886743941356e-09was produced
# 70% complete
#  after 7 iterations an estimate with error of F =3.9200960075567294e-11 and delta = 4.9918928869924044e-09was produced
#  after 11 iterations an estimate with error of F =3.4590360227900506e-11 and delta = 3.7186247425422537e-09was produced
#  after 9 iterations an estimate with error of F =3.4468485587542097e-10 and delta = 1.8619999206266413e-08was produced
#  after 22 iterations an estimate with error of F =2.122067673803037e-09 and delta = 4.726931799754679e-08was produced
#  after 13 iterations an estimate with error of F =7.991645862562773e-10 and delta = 2.362543730521735e-08was produced
#  after 39 iterations an estimate with error of F =4.5769366985704415e-09 and delta = 6.841023563456255e-08was produced
#  after 15 iterations an estimate with error of F =1.2555199285222426e-09 and delta = 3.8254820343340606e-08was produced
#  after 31 iterations an estimate with error of F =5.393793545431996e-09 and delta = 9.135183220757941e-08was produced
#  after 17 iterations an estimate with error of F =2.88090821563218e-09 and delta = 8.681166009903157e-08was produced
#  after 28 iterations an estimate with error of F =4.8807972099549754e-09 and delta = 8.991206944994658e-08was produced
# 75% complete
#  after 25 iterations an estimate with error of F =2.369920248052317e-09 and delta = 6.609426526010892e-08was produced
#  after 30 iterations an estimate with error of F =5.437976290075631e-09 and delta = 9.273770594567116e-08was produced
# 75% complete
#  after 22 iterations an estimate with error of F =2.2419008114865957e-09 and delta = 6.470102806517195e-08was produced
#  after 36 iterations an estimate with error of F =5.747516228879989e-09 and delta = 8.757513534628234e-08was produced
#  after 18 iterations an estimate with error of F =1.3731471501775073e-09 and delta = 4.1216302800563926e-08was produced
#  after 27 iterations an estimate with error of F =2.8487485519918018e-09 and delta = 5.495663767559742e-08was produced
#  after 12 iterations an estimate with error of F =1.4593429838938287e-09 and delta = 4.3339881834548073e-08was produced
#  after 11 iterations an estimate with error of F =3.2259033371301813e-10 and delta = 3.0577773600759396e-08was produced
#  after 7 iterations an estimate with error of F =1.9977987879897748e-10 and delta = 1.7676045554898295e-08was produced
#  after 6 iterations an estimate with error of F =7.877627518933041e-12 and delta = 1.3977540137720586e-08was produced
#  after 7 iterations an estimate with error of F =8.878328679022668e-11 and delta = 1.2552287836480797e-08was produced
#  after 11 iterations an estimate with error of F =7.570496774877555e-11 and delta = 7.995936314527314e-09was produced
# 80% complete
#  after 9 iterations an estimate with error of F =7.850672839205099e-10 and delta = 3.635162218301171e-08was produced
#  after 20 iterations an estimate with error of F =4.208624753254792e-09 and delta = 9.747769406708228e-08was produced
# 80% complete
#  after 13 iterations an estimate with error of F =8.952254935003581e-10 and delta = 2.658879322088069e-08was produced
#  after 39 iterations an estimate with error of F =4.489892457695511e-09 and delta = 6.717515493785401e-08was produced
#  after 14 iterations an estimate with error of F =2.1751773497781277e-09 and delta = 6.632209936920387e-08was produced
#  after 32 iterations an estimate with error of F =3.503140027390329e-09 and delta = 5.8861833254654325e-08was produced
#  after 18 iterations an estimate with error of F =2.84769253785427e-09 and delta = 8.55558608625974e-08was produced
#  after 28 iterations an estimate with error of F =5.146023079254428e-09 and delta = 9.441925745351385e-08was produced
#  after 23 iterations an estimate with error of F =2.7271362886274625e-09 and delta = 7.75014321094648e-08was produced
#  after 29 iterations an estimate with error of F =4.06253671196623e-09 and delta = 7.303576992516017e-08was produced
#  after 20 iterations an estimate with error of F =2.6568512552111845e-09 and delta = 7.79304950120528e-08was produced
#  after 33 iterations an estimate with error of F =5.017442262769623e-09 and delta = 8.116607178720045e-08was produced
# 85% complete
#  after 16 iterations an estimate with error of F =1.6758359695518523e-09 and delta = 5.0431816287831886e-08was produced
#  after 37 iterations an estimate with error of F =6.387966024614521e-09 and delta = 9.85602018262383e-08was produced
# 85% complete
#  after 10 iterations an estimate with error of F =2.4715785845014546e-09 and delta = 7.478767700410618e-08was produced
#  after 17 iterations an estimate with error of F =1.872590232851764e-09 and delta = 5.2260334552680495e-08was produced
#  after 6 iterations an estimate with error of F =1.1444248594890834e-10 and delta = 3.7237710739149033e-08was produced
#  after 9 iterations an estimate with error of F =9.257113256951484e-11 and delta = 1.2676098001548843e-08was produced
#  after 7 iterations an estimate with error of F =1.2280391676271951e-11 and delta = 2.588523191651302e-09was produced
#  after 10 iterations an estimate with error of F =3.930105936788274e-10 and delta = 3.837480782193537e-08was produced
#  after 8 iterations an estimate with error of F =2.520390049094779e-09 and delta = 9.527482560771578e-08was produced
#  after 13 iterations an estimate with error of F =1.5048154047846269e-09 and delta = 5.207897422395596e-08was produced
#  after 13 iterations an estimate with error of F =1.3644807447531725e-09 and delta = 4.087290298297249e-08was produced
#  after 32 iterations an estimate with error of F =3.6229560971831796e-09 and delta = 6.175159419123319e-08was produced
# 90% complete
#  after 17 iterations an estimate with error of F =1.8080718379816794e-09 and delta = 5.497241172904885e-08was produced
#  after 35 iterations an estimate with error of F =3.9632282359268996e-09 and delta = 6.188962357353017e-08was produced
# 90% complete
#  after 20 iterations an estimate with error of F =2.0600249478048963e-09 and delta = 6.126725024773946e-08was produced
#  after 29 iterations an estimate with error of F =5.343862463582095e-09 and delta = 9.394139232112301e-08was produced
#  after 22 iterations an estimate with error of F =1.8431123326859277e-09 and delta = 5.323205825162126e-08was produced
#  after 28 iterations an estimate with error of F =4.311475109994006e-09 and delta = 8.029693513520138e-08was produced
#  after 19 iterations an estimate with error of F =1.6759208075404525e-09 and delta = 4.974600302343694e-08was produced
#  after 30 iterations an estimate with error of F =5.490215986610138e-09 and delta = 9.539141642891677e-08was produced
#  after 14 iterations an estimate with error of F =1.6545971131909084e-09 and delta = 4.98181780166308e-08was produced
#  after 37 iterations an estimate with error of F =4.595930013048124e-09 and delta = 7.03370355288237e-08was produced
#  after 10 iterations an estimate with error of F =2.211874637191266e-09 and delta = 6.782698670163178e-08was produced
#  after 29 iterations an estimate with error of F =3.798280778440255e-09 and delta = 6.942279585310253e-08was produced
# 95% complete
#  after 7 iterations an estimate with error of F =1.545696102030809e-11 and delta = 4.0553374088043075e-09was produced
#  after 11 iterations an estimate with error of F =9.238823768736254e-10 and delta = 4.557431236134837e-08was produced
# 95% complete
#  after 7 iterations an estimate with error of F =5.885561493979466e-12 and delta = 3.103569689628736e-09was produced
#  after 8 iterations an estimate with error of F =8.091395450899107e-11 and delta = 1.365860293114036e-08was produced
#  after 9 iterations an estimate with error of F =1.5785750343025462e-09 and delta = 5.813204801678385e-08was produced
#  after 10 iterations an estimate with error of F =8.801748887151932e-10 and delta = 8.128360163760749e-08was produced
#  after 14 iterations an estimate with error of F =1.5829456491190176e-09 and delta = 4.756733258894451e-08was produced
#  after 20 iterations an estimate with error of F =1.9550378011930534e-09 and delta = 4.631629667942193e-08was produced
#  after 18 iterations an estimate with error of F =2.0763756752038153e-09 and delta = 6.276536855413875e-08was produced
#  after 36 iterations an estimate with error of F =6.01100516217089e-09 and delta = 9.184043659937857e-08was produced
#  after 21 iterations an estimate with error of F =2.6141691496238045e-09 and delta = 7.674563595844836e-08was produced
#  after 31 iterations an estimate with error of F =5.824239288237749e-09 and delta = 9.584695617421768e-08was produced
# 100% complete

# %% [markdown]
# Importing already computed data

# %%
P = np.load("P.npy")
Q = np.load("Q.npy")
yvals = np.load("yvals.npy")
xvals = np.load("xvals.npy")
ForcingParameters = np.load("ForcingParameters.npy")
tindices = np.load("tindices.npy")
t = np.load("t.npy")
Xhyp = np.load("Xhyp.npy")
Q =np.linspace(-2,2,10)
N = 201

trangestart = N//5
trangeend = 4*trangestart
#tindices = np.arange(int(N//5),int(4*N//5),10)
#tindices = np.array([3*N//4])
trange = t[tindices]

# %%
interpyS = makeinterpyS(P,yvals,tindices)
interpxU = makeinterpxU(Q,xvals,tindices)

Pinterp = np.linspace(P[0]+0.1,P[-1]-0.1,15)
Qinterp = np.linspace(Q[0]+0.1,Q[-1]-0.1,15)
for J in tindices:
    Yvals =0*Pinterp
    Xvals = 0*Qinterp
    for i in range(0,len(Pinterp)):
        Yvals[i] = ySM(Pinterp[i],t[J])
    ax.plot(Pinterp[:]+Xhyp[J][0],Yvals[:] ,t[J], color = 'green', linewidth=3, marker='x')
    #plt.legend(fontsize=14)
    for i in range(0,len(Qinterp)):
        Xvals[i] = xUM(Qinterp[i],t[J])
    ax.plot(Xvals[:],Qinterp[:] + Xhyp[J][1],t[J], color = 'blue', linewidth=3, marker='x')
    
    ax.set_xlabel("$x$", fontsize=14)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
    ax.set_ylabel("$y$", fontsize=14)
    ax.set_zlabel("$t$", fontsize=14)
    plt.show()

# %% [markdown]
# ## Plots
# ----

# %% [markdown]
# Manifolds in original coordinates.

# %%
#Changing coordinates back to original
Minv = (lplus - lminus)**(-1)*np.array([[lplus,-1],[-lminus,1]])
M = np.linalg.inv(Minv)
fig = plt.figure(figsize=(15,15))
Pinterp = np.linspace(P[0]+0.1,P[-1]-0.1,15)
Qinterp = np.linspace(Q[0]+0.1,Q[-1]-0.1,15)
J= 100
Yvals =0*Pinterp
Original = 0*Xhyp

for i in range(0,Original.shape[0]):
    Original[i] = M.dot(Xhyp[i])

for i in range(0,len(Pinterp)):
    Yvals[i] = ySM(Pinterp[i],t[J])
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
ax.plot(Original[:,0], Original[:,1], (lplus-lminus)*t,linestyle='--', color = 'green', linewidth=3, marker='o', label="Non-linear hyperbolic trajectory")
Pinterp = np.linspace(P[0]+0.1,P[-1]-0.1,15)
Qinterp = np.linspace(Q[0]+0.1,Q[-1]-0.1,15)
for J in tindices:
    Yvals =0*Pinterp
    Xvals = 0*Qinterp
    for i in range(0,len(Pinterp)):
        Yvals[i] = ySM(Pinterp[i],t[J])
    if J == tindices[0]:
        ax.plot(M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[0],M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[1] ,(lplus-lminus)*t[J], color = 'blue', linewidth=3, marker='x',label = 'Stable manifold')
    else:
        ax.plot(M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[0],M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[1] ,(lplus-lminus)*t[J], color = 'blue', linewidth=3, marker='x')
    
    for i in range(0,len(Qinterp)):
        Xvals[i] = xUM(Qinterp[i],t[J])
    if J ==tindices[0]:
        ax.plot(M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[0],M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[1],(lplus-lminus)*t[J], color = 'red', linewidth=3, marker='x',label = "Unstable manifold")
    else:
        ax.plot(M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[0],M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[1],(lplus-lminus)*t[J], color = 'red', linewidth=3, marker='x')
    ax.set_xlabel("$x$", fontsize=14)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
    plt.legend()
    ax.set_ylabel("$y$", fontsize=14)
    ax.set_zlabel("$t$", fontsize=14)
    plt.show()

# %% [markdown]
# Time slice in original coordinates.

# %%
    
# changing coords    
    
plt.plot(M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[0], M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[1]   ,         color = 'blue', linewidth=3, marker='x', label = "Stable manifold")
plt.plot(Original[J,0],Original[J,1],marker = 'o',label ="hyp traj",color = 'green')
for i in range(0,len(Qinterp)):
        Xvals[i] = xUM(Qinterp[i],t[J])
plt.plot(M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[0],M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[1], color = 'red', linewidth=3, marker='x',label = 'Unstable manifold')
    
plt.legend(fontsize=14)
plt.xlabel("$x$", fontsize=14)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
plt.ylabel("$y$", fontsize=14)
plt.show()

# %% [markdown]
# # Heat map
# ----

# %%
xhyp = lambda s: np.interp(s,(lplus-lminus)*t,Original[:,0])
yhyp = lambda s: np.interp(s,(lplus-lminus)*t,Original[:,1])

# %%
# functions to determine if it passes over
f = lambda t,y : np.array([y[1], np.tanh(y[0])*np.cosh(y[0])**(-2) - k*y[1]]+(lplus-lminus)*G((lplus-lminus)*t)) # vector field in original coordinates
#fig = plt.figure(figsize=(15,15))
def event(s,y):
    #return (Minv.dot(y) - np.array([xhyp(s),yhyp(s)]))[0]
    return y[0]- xhyp(s)
event.terminal = True
# functions to determine if it passes over
def passOver(y0):
    if event(0,y0) < 0:
        res = solve_ivp (f, [0,100], y0 , method = "RK45" , events=[event],max_step =0.05 , rtol = 1e-8 )
        y = res .y. transpose()
        t = res .t  
        s = t[-1]
        if s<100 and y[-1][1] > yhyp(s):  # the trajectories which move left to right
            return s
        elif y[-1][0]- xhyp(s) < 0: # trajectories which stay on left
            return -1
    else: 
        res = solve_ivp (f, [0,100], y0 , method = "RK45" , events=[event],max_step =0.05 , rtol = 1e-8 )
        y = res .y. transpose()
        t = res .t  
        s = t[-1]
        if s<100 and y[-1][1] < yhyp(s):  # the trajectories which move right to left 
            return 0
        elif y[-1][0]- xhyp(s) > 0: # trajectories which stay on right
            return 0



#creating and storing the data.

x = np.meshgrid(np.linspace(-3, 3,100) , np.linspace(-3,3,100),indexing= 'ij')
z = np.zeros((np.shape(x)[1],np.shape(x)[2]))
for i in range(0,np.shape(x)[1]):
    for j in range(0,np.shape(x)[2]):
        y0 = np.array([x[0][i,j],x[1][i,j]])
        z[i,j] = passOver(y0)
np.save("initial conditions.npy" , x)
np.save("Points moving over.npy", z)

# %%
fig = plt.figure(figsize=(15,15)) 
plt.plot(M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[0], M.dot(np.array([Pinterp[:]+Xhyp[J][0],Yvals[:]]))[1]   ,         color = 'blue', linewidth=3, marker='x', label = "Stable manifold")
plt.plot(Original[J,0],Original[J,1],marker = 'o',label ="hyp traj",color = 'green')
for i in range(0,len(Qinterp)):
        Xvals[i] = xUM(Qinterp[i],t[J])
plt.plot(M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[0],M.dot(np.array([Xvals[:],Qinterp[:] + Xhyp[J][1]]))[1], color = 'red', linewidth=3, marker='x',label = 'Unstable manifold')
    
plt.legend(fontsize=14)
plt.xlabel("$x$", fontsize=14)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
plt.ylabel("$y$", fontsize=14)
plt.show()
plt.contourf(x[0][:],x[1][:],z)
plt.colorbar()
plt.xlabel("x", fontsize=14)
plt.ylabel("y", fontsize=14)
plt.show()

# %% [markdown]
# ## Old plots
# ----

# %% [markdown]
# Plot of  manifolds in stable/unstable coordinates.

# %%
# %matplotlib qt
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
ax.plot(Xhyp[:,0], Xhyp[:,1], t,linestyle='--', color = 'green', linewidth=3, marker='o', label="Hyperbolic trajectory")
Pinterp = np.linspace(P[0]+0.1,P[-1]-0.1,15)
Qinterp = np.linspace(Q[0]+0.1,Q[-1]-0.1,15)
for J in tindices:
    Yvals =0*Pinterp
    Xvals = 0*Qinterp
    for i in range(0,len(Pinterp)):
        Yvals[i] = ySM(Pinterp[i],t[J])
    if J == tindices[0]:
        ax.plot(Pinterp[:]+Xhyp[J][0],Yvals[:] ,t[J], color = 'blue', linewidth=3, marker='x',label = "Stable manifold")
    else:
        ax.plot(Pinterp[:]+Xhyp[J][0],Yvals[:] ,t[J], color = 'blue', linewidth=3, marker='x')
    
    for i in range(0,len(Qinterp)):
        Xvals[i] = xUM(Qinterp[i],t[J])
        
    if J == tindices[0]:
        ax.plot(Xvals[:],Qinterp[:] + Xhyp[J][1],t[J], color = 'red', linewidth=3, marker='x', label = "Unstable manifold")
    else:
        ax.plot(Xvals[:],Qinterp[:] + Xhyp[J][1],t[J], color = 'red', linewidth=3, marker='x')
    
    plt.legend(fontsize = 14)
    ax.set_xlabel("$x$", fontsize=14)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
    ax.set_ylabel("$y$", fontsize=14)
    ax.set_zlabel("$t$", fontsize=14)
    plt.show()

# %% [markdown]
# Time slice in stable/unstable coordinates

# %%
fig = plt.figure(figsize=(15,15))
Pinterp = np.linspace(P[0]+0.1,P[-1]-0.1,15)
Qinterp = np.linspace(Q[0]+0.1,Q[-1]-0.1,15)
J= 100
Yvals =0*Pinterp
for i in range(0,len(Pinterp)):
    Yvals[i] = ySM(Pinterp[i],t[J])
plt.plot(Pinterp[:]+Xhyp[J][0],Yvals[:], color = 'blue', linewidth=3, marker='x', label = "stable manifold")
plt.plot(Xhyp[J][0],Xhyp[J][1],marker = 'o',label ="hyp traj",color = 'green')
for i in range(0,len(Qinterp)):
        Xvals[i] = xUM(Qinterp[i],t[J])
plt.plot(Xvals[:],Qinterp[:] + Xhyp[J][1],t[J], color = 'red', linewidth=3, marker='x',label = 'unstable manifold')
    
plt.legend(fontsize=14)
plt.xlabel("$x$", fontsize=14)
    #plt.xlim(-1, 1)
    #plt.ylim(-1, 1)
plt.ylabel("$y$", fontsize=14)
plt.show()
